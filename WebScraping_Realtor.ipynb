# %%
#For Scraping
import requests
from bs4 import BeautifulSoup as soup

#For storing results in JSON format
import json

#To handle some duplications in scrapped data
import re

#To resolve IP address block issues
import random

# %%
#Target Url
url = "https://www.realtor.com/realestateandhomes-search/Los-Angeles_CA"

#A list of different user agents to use in case of blockage
user_agents = ['Chrome/83.0.4103.97', "Chrome/22.0.1207.1",
               "Chrome/20.0.1132.57",
        "Chrome/20.0.1092.0"]

#Check for success of get request
code = 0

#The loop will run with different agents until success
while code != 200 :

  user_agent = random.choice(user_agents)

  html = requests.get(url = url, headers={"User-Agent": user_agent, "referer" : "https://www.realtor.com/realestateandhomes-search/Los-Angeles_CA"})

  print(html.status_code)

  code = html.status_code

print("Success")
# Out:
# 200
# Success

# %%
raw_data = soup(html.content)
raw_data
# Out:
# <!DOCTYPE html>
# <html lang="en"><head><meta charset="utf-8"/><script>window.kxdl = { jy: '' };  window.rdcdl = window.kxdl;  !function(n,e,i){if(!n){n=n||{},window.permutive=n,n.q=[],n.config=i||{},n.config.apiKey=e,n.config.environment=n.config.environment||'production';for(var o=['addon','identify','track','trigger','query','segment','segments','ready','on','once','user','consent'],r=0;r<o.length;r++){var t=o[r];n[t]=function(e){return function(){var i=Array.prototype.slice.call(arguments,0);n.q.push({functionName:e,arguments:i})}}(t)}}}(window.permutive,'2336e88c-2653-4e72-9d49-c562730fd85f',{});(function(g,o){g[o]=g[o]||function(){(g[o]['q']=g[o]['q']||[]).push(arguments)},g[o]['t']=1*new Date})(window,'_googCsa');</script><script async="" data-testid="dfp" fetchpriority="auto" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script><script async="" data-testid="prebid" fetchpriority="auto" src="https://pbcs.realtor.com/p/realtor/realtor/pb.js"></script><script async="" data-testid="amazon" fetchpriority="auto" src="https://c.amazon-adsystem.com/aax2/apstag.js"></script><script async="" data-testid="permutive" fetchpriority="auto" src="https://0cf17917-395b-4f25-91cc-db3bdd6044b0.edge.permutive.app/5dc35e4e-c442-405b-bf5f-5c2b8824b0cf-web.js"></script><script async="" data-testid="openwrap" fetchpriority="auto" src="https://ads.pubmatic.com/AdServer/js/pwt/162281/7793/pwt.js"></script><script async="" data-testid="adsense" fetchpriority="auto" src="https://www.google.com/adsense/search/ads.js"></script><script async="" data-testid="adlightning" fetchpriority="auto" src="https://tagan.adlightning.com/realtor/op.js"></script><title>Los Angeles, CA Real Estate - Los Angeles Homes for Sale | realtor.com®</title><link href="https://www.realtor.com/realestateandhomes-search/Los-Angeles_CA" rel="canonical"/><meta content="View 8050 homes for sale in Los Angeles, CA at a median listing home price of $1,219,500. See pricing and listing details of Los Angeles real estate for sale." name="description"/><meta content="https://www.realtor.com/realestateandhomes-search/Los-Angeles_CA" property="og:url"/><meta content="Los Angeles, CA Real Estate - Los Angeles Homes for Sale | realtor.com®" property="og:title"/><meta content="View 8050 homes for sale in Los Angeles, CA at a median listing home price of $1,219,500. See pricing and listing details of Los Angeles real estate for sale." property="og:description"/><meta content="https://ap.rdcpix.com/03c22078a06cd1bbd7a73a45a0ad6a08l-m1746835519od-w480_h480_q80.jpg" property="og:image"/><meta content="realtor.com®" property="og:site_name"/><meta content="View 8050 homes for sale in Los Angeles, CA at a median listing home price of $1,219,500. See pricing and listing details of Los Angeles real estate for sale." property="twitter:description"/><meta content="https://ap.rdcpix.com/03c22078a06cd1bbd7a73a45a0ad6a08l-m1746835519od-w480_h480_q80.jpg" property="twitter:image"/><meta content="@realtordotcom" name="twitter:site"/><meta content="website" property="og:type"/><meta content="480" property="og:image:width"/><meta content="480" property="og:image:height"/><meta content="rdc-x-web-rc/v10.319" name="app-version"/><meta content="false" data-useragent="Chrome/22.0.1207.1" name="isbot"/><meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/><link as="image" href="https://ap.rdcpix.com/03c22078a06cd1bbd7a73a45a0ad6a08l-m1746835519od-w480_h360_x2.webp" rel="preload" type="image/webp"/><link as="image" href="https://ap.rdcpix.com/3e1611cd75acb31f6b52937e6a39dc8cl-m2874584623od-w480_h360_x2.webp" rel="preload" type="image/webp"/><link as="image" href="https://ap.rdcpix.com/de4477e7fc217f575a7ca3df1a9b18e5l-m1768215027od-w480_h360_x2.webp" rel="preload" type="image/webp"/><meta content="22" name="next-head-count"/><link crossorigin="true" href="https://cdn.optimizely.com" rel="preconnect"/><link href="https://static.rdc.moveaws.com/touch-icon.png" rel="touch-icon"/><link hr ...
# (()=>{var e,t,r={234:(e,t,r)=>{"use strict";r.d(t,{P_:()=>g,Mt:()=>v,C5:()=>s,DL:()=>A,OP:()=>D,lF:()=>N,Yu:()=>x,Dg:()=>m,CX:()=>c,GE:()=>w,sU:()=>j});var n=r(8632),i=r(9567);const o={beacon:n.ce.beacon,errorBeacon:n.ce.errorBeacon,licenseKey:void 0,applicationID:void 0,sa:void 0,queueTime:void 0,applicationTime:void 0,ttGuid:void 0,user:void 0,account:void 0,product:void 0,extra:void 0,jsAttributes:{},userAttributes:void 0,atts:void 0,transactionName:void 0,tNamePlain:void 0},a={};function s(e){if(!e)throw new Error("All info objects require an agent identifier!");if(!a[e])throw new Error("Info for ".concat(e," was never set"));return a[e]}function c(e,t){if(!e)throw new Error("All info objects require an agent identifier!");a[e]=(0,i.D)(t,o);const r=(0,n.ek)(e);r&&(r.info=a[e])}const u=e=>{if(!e||"string"!=typeof e)return!1;try{document.createDocumentFragment().querySelector(e)}catch{return!1}return!0};var d=r(7056),l=r(50);const f=()=>{const e={mask_selector:"*",block_selector:"[data-nr-block]",mask_input_options:{color:!1,date:!1,"datetime-local":!1,email:!1,month:!1,number:!1,range:!1,search:!1,tel:!1,text:!1,time:!1,url:!1,week:!1,textarea:!1,select:!1,password:!0}};return{feature_flags:[],proxy:{assets:void 0,beacon:void 0},privacy:{cookies_enabled:!0},ajax:{deny_list:void 0,block_internal:!0,enabled:!0,harvestTimeSeconds:10,autoStart:!0},distributed_tracing:{enabled:void 0,exclude_newrelic_header:void 0,cors_use_newrelic_header:void 0,cors_use_tracecontext_headers:void 0,allowed_origins:void 0},session:{domain:void 0,expiresMs:d.oD,inactiveMs:d.Hb},ssl:void 0,obfuscate:void 0,jserrors:{enabled:!0,harvestTimeSeconds:10,autoStart:!0},metrics:{enabled:!0,autoStart:!0},page_action:{enabled:!0,harvestTimeSeconds:30,autoStart:!0},page_view_event:{enabled:!0,autoStart:!0},page_view_timing:{enabled:!0,harvestTimeSeconds:30,long_task:!1,autoStart:!0},session_trace:{enabled:!0,harvestTimeSeconds:10,autoStart:!0},harvest:{tooManyRequestsDelay:60},session_replay:{autoStart:!0,enabled:!1,harvestTimeSeconds:60,sampling_rate:50,error_sampling_rate:50,collect_fonts:!1,inline_images:!1,inline_stylesheet:!0,mask_all_inputs:!0,get mask_text_selector(){return e.mask_selector},set mask_text_selector(t){u(t)?e.mask_selector=t+",[data-nr-mask]":null===t?e.mask_selector=t:(0,l.Z)("An invalid session_replay.mask_selector was provided and will not be used",t)},get block_class(){return"nr-block"},get ignore_class(){return"nr-ignore"},get mask_text_class(){return"nr-mask"},get block_selector(){return e.block_selector},set block_selector(t){u(t)?e.block_selector+=",".concat(t):""!==t&&(0,l.Z)("An invalid session_replay.block_selector was provided and will not be used",t)},get mask_input_options(){return e.mask_input_options},set mask_input_options(t){t&&"object"==typeof t?e.mask_input_options={...t,password:!0}:(0,l.Z)("An invalid session_replay.mask_input_option was provided and will not be used",t)}},spa:{enabled:!0,harvestTimeSeconds:10,autoStart:!0}}},h={},p="All configuration objects require an agent identifier!";function g(e){if(!e)throw new Error(p);if(!h[e])throw new Error("Configuration for ".concat(e," was never set"));return h[e]}function m(e,t){if(!e)throw new Error(p);h[e]=(0,i.D)(t,f());const r=(0,n.ek)(e);r&&(r.init=h[e])}function v(e,t){if(!e)throw new Error(p);var r=g(e);if(r){for(var n=t.split("."),i=0;i<n.length-1;i++)if("object"!=typeof(r=r[n[i]]))return;r=r[n[n.length-1]]}return r}const b={accountID:void 0,trustKey:void 0,agentID:void 0,licenseKey:void 0,applicationID:void 0,xpid:void 0},y={};function A(e){if(!e)throw new Error("All loader-config objects require an agent identifier!");if(!y[e])throw new Error("LoaderConfig for ".concat(e," was never set"));return y[e]}function w(e,t){if(!e)throw new Error("All loader-config objects require an agent identifier!");y[e]=(0,i.D)(t,b);const r=(0,n.ek)(e);r&&(r.loader_config=y[e])}const x=(0,n.mF)().o;var E=r(385),_=r(6818);const T={buildEnv:_.Re,customTransaction:void 0,disabled:! ...
# .icakrD[type='number']::-webkit-inner-spin-button,.icakrD[type='number']::-webkit-outer-spin-button{margin:0;}/*!sc*/
# data-styled.g1[id="InputElement-rui__kzcwvy-0"]{content:"icakrD,"}/*!sc*/
# .fPPgsD{border:1px solid transparent;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;max-width:100%;min-height:40px;-webkit-transition:border-color 100ms cubic-bezier(0.5,0,0.2,1);transition:border-color 100ms cubic-bezier(0.5,0,0.2,1);background-color:#FFFFFF;}/*!sc*/
# data-styled.g2[id="InputGroup-rui__hn7d6j-0"]{content:"fPPgsD,"}/*!sc*/
# .dytNJW{display:inline-block;width:-webkit-max-content;width:-moz-max-content;width:max-content;}/*!sc*/
# data-styled.g3[id="Popperstyles__PopperAnchorWrapper-rui__sc-1tp3q5v-0"]{content:"dytNJW,"}/*!sc*/
# .TOPhc{background-color:transparent;background-image:none;border:0;cursor:pointer;height:16px;overflow:hidden;padding:calc(calc(16px / 2) + 14px);position:relative;width:16px;}/*!sc*/
# .TOPhc:before,.TOPhc:after{border-radius:40px;background-color:#FFFFFF;content:' ';height:16px;position:absolute;top:14px;width:2px;}/*!sc*/
# .TOPhc:before{-webkit-transform:rotate(45deg);-ms-transform:rotate(45deg);transform:rotate(45deg);}/*!sc*/
# .TOPhc:after{-webkit-transform:rotate(-45deg);-ms-transform:rotate(-45deg);transform:rotate(-45deg);}/*!sc*/
# @media (hover:hover) and (pointer:fine){.TOPhc:hover:before,.TOPhc:hover:after{background-color:#DFDFDF;}}/*!sc*/
# .TOPhc:focus:before,.TOPhc:focus:after{background-color:#DFDFDF;}/*!sc*/
# .jRdpTA{background-color:transparent;background-image:none;border:0;cursor:pointer;height:24px;overflow:hidden;padding:calc(calc(24px / 2) + 14px);position:relative;width:24px;}/*!sc*/
# .jRdpTA:before,.jRdpTA:after{border-radius:40px;background-color:#2B2B2B;content:' ';height:24px;position:absolute;top:14px;width:2px;}/*!sc*/
# .jRdpTA:before{-webkit-transform:rotate(45deg);-ms-transform:rotate(45deg);transform:rotate(45deg);}/*!sc*/
# .jRdpTA:after{-webkit-transform:rotate(-45deg);-ms-transform:rotate(-45deg);transform:rotate(-45deg);}/*!sc*/
# @media (hover:hover) and (pointer:fine){.jRdpTA:hover:before,.jRdpTA:hover:after{background-color:#646464;}}/*!sc*/
# .jRdpTA:focus:before,.jRdpTA:focus:after{background-color:#646464;}/*!sc*/
# .ldxwiU{background-color:transparent;background-image:none;border:0;cursor:pointer;height:20px;overflow:hidden;padding:calc(calc(20px / 2) + 14px);position:relative;width:20px;}/*!sc*/
# .ldxwiU:before,.ldxwiU:after{border-radius:40px;background-color:#2B2B2B;content:' ';height:20px;position:absolute;top:14px;width:2px;}/*!sc*/
# .ldxwiU:before{-webkit-transform:rotate(45deg);-ms-transform:rotate(45deg);transform:rotate(45deg);}/*!sc*/
# .ldxwiU:after{-webkit-transform:rotate(-45deg);-ms-transform:rotate(-45deg);transform:rotate(-45deg);}/*!sc*/
# @media (hover:hover) and (pointer:fine){.ldxwiU:hover:before,.ldxwiU:hover:after{background-color:#646464;}}/*!sc*/
# .ldxwiU:focus:before,.ldxwiU:focus:after{background-color:#646464;}/*!sc*/
# data-styled.g7[id="CloseButtonstyles__StyledCloseButton-rui__h4a9jf-0"]{content:"TOPhc,jRdpTA,ldxwiU,"}/*!sc*/
# .hhZQzR{font-size:12px;line-height:16px;font-weight:700;text-align:inherit;color:#FFFFFF;}/*!sc*/
# @media (max-width:767px){.hhZQzR{font-weight:700;}}/*!sc*/
# .eRRmbh{font-size:14px;line-height:inherit;font-weight:500;text-align:inherit;color:#2B2B2B;}/*!sc*/
# @media (max-width:767px){.eRRmbh{line-height:inherit;font-weight:500;}}/*!sc*/
# .mvAUu{font-size:14px;line-height:20px;font-weight:700;text-align:inherit;color:#2B2B2B;}/*!sc*/
# @media (max-width:767px){.mvAUu{font-weight:700;}}/*!sc*/
# .hyPBXg{font-size:14px;line-height:20px;font-weight:400;text-align:inherit;color:#2B2B2B;white-space:nowrap;overflow:hidden;text-overflow:ellipsis;}/*!sc*/
# .gCzmlw{font-size:14px;line-height:20px;font-weight:400;text-align:inherit;color:#2B2B2B;margin-bottom:8px;}/*!sc*/
# .coGdIm{font-size:14px;line-height:20px;font-weight:400;text-align:inherit;color:#2B2B2B;margin-top:16px;margin-bottom:8px;}/*!sc*/
# .dzWDTf{font-size:16px;line-height:24px;font-weight:400;text-align:inherit;color:#2B2B2B;}/*!sc*/
# .iZQYTO{font-size:16px;line-height:24px;font-weight:400;text-align:inherit;color:#2B2B2B;white-space:nowrap;overflow:hidden;text-overflow:ellipsis;}/*!sc*/
# .kpUjhd{font-size:14px;line-height:20px;font-weight:400;text-align:inherit;color:#2B2B2B;}/*!sc*/
# .kpqWov{font-size:20px;line-height:32px;-webkit-letter-spacing:0.6px;-moz-letter-spacing:0.6px;-ms-letter-spacing:0.6px;letter-spacing:0.6px;font-weight:700;text-align:inherit;color:#2B2B2B;margin-bottom:8px;}/*!sc*/
# @media (max-width:767px){.kpqWov{font-size:18px;line-height:24px;-webkit-letter-spacing:0.6px;-moz-letter-spacing:0.6px;-ms-letter-spacing:0.6px;letter-spacing:0.6px;font-weight:700;}}/*!sc*/
# .iAbDCa{font-size:20px;line-height:32px;-webkit-letter-spacing:0.6px;-moz-letter-spacing:0.6px;-ms-letter-spacing:0.6px;letter-spacing:0.6px;font-weight:700;text-align:inherit;color:#2B2B2B;}/*!sc*/
# @media (max-width:767px){.iAbDCa{font-size:18px;line-height:24px;-webkit-letter-spacing:0.6px;-moz-letter-spacing:0.6px;-ms-letter-spacing:0.6px;letter-spacing:0.6px;font-weight:700;}}/*!sc*/
# .loCKQc{font-size:16px;line-height:24px;font-weight:700;text-align:inherit;color:#2B2B2B;}/*!sc*/
# @media (max-width:767px){.loCKQc{font-weight:700;}}/*!sc*/
# .epeOAC{font-size:20px;line-height:32px;-webkit-letter-spacing:0.6px;-moz-letter-spacing:0.6px;-ms-letter-spacing:0.6px;letter-spacing:0.6px;font-weight:700;text-align:inherit;color:#2B2B2B;margin-top:8px;margin-bottom:8px;}/*!sc*/
# @media (max-width:767px){.epeOAC{font-size:18px;line-height:24px;-webkit-letter-spacing:0.6px;-moz-letter-spacing:0.6px;-ms-letter-spacing:0.6px;letter-spacing:0.6px;font-weight:700;}}/*!sc*/
# .iOBDUi{font-size:20px;line-height:32px;-webkit-letter-spacing:0.6px;-moz-letter-spacing:0.6px;-ms-letter-spacing:0.6px;letter-spacing:0.6px;font-weight:700;text-align:inherit;color:#FFFFFF;}/*!sc*/
# @media (max-width:767px){.iOBDUi{font-size:18px;line-height:24px;-webkit-letter-spacing:0.6px;-moz-letter-spacing:0.6px;-ms-letter-spacing:0.6px;letter-spacing:0.6px;font-weight:700;}}/*!sc*/
# .dBGWku{font-size:12px;line-height:16px;font-weight:400;text-align:inherit;color:#2B2B2B;}/*!sc*/
# .klRdja{font-size:18px;line-height:24px;font-weight:700;text-align:inherit;color:#2B2B2B;}/*!sc*/
# @media (max-width:767px){.klRdja{font-weight:700;}}/*!sc*/
# .fWgYAL{font-size:14px;line-height:20px;font-weight:400;text-align:inherit;color:#2B2B2B;margin-bottom:16px;}/*!sc*/
# .bSZnAh{font-size:16px;line-height:24px;font-weight:700;text-align:inherit;color:#2B2B2B;}/*!sc*/
# @media (max-width:767px){.bSZnAh{font-size:16px;font-weight:700;}}/*!sc*/
# .ezenPO{font-size:14px;line-height:20px;font-weight:400;text-align:inherit;color:#2B2B2B;}/*!sc*/
# @media (max-width:767px){.ezenPO{font-weight:400;}}/*!sc*/
# data-styled.g8[id="base__StyledType-rui__sc-108xfm0-0"]{content:"hhZQzR,eRRmbh,mvAUu,hyPBXg,gCzmlw,coGdIm,dzWDTf,iZQYTO,kpUjhd,kpqWov,iAbDCa,loCKQc,epeOAC,iOBDUi,dBGWku,klRdja,fWgYAL,bSZnAh,ezenPO,"}/*!sc*/
# .enGXSt{color:#2B2B2B;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;margin-bottom:4px;margin-top:0;}/*!sc*/
# .enGXSt .label-hint{display:block;position:relative;height:20px;width:20px;}/*!sc*/
# .enGXSt .label-hint svg{left:50%;position:absolute;top:50%;-webkit-transform:translate(-50%,-50%);-ms-transform:translate(-50%,-50%);transform:translate(-50%,-50%);}/*!sc*/
# @media (hover:hover) and (pointer:fine){.enGXSt .label-hint:hover{cursor:pointer;}}/*!sc*/
# .ezbrTK{color:#2B2B2B;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;margin-bottom:4px;margin-top:0;cursor:pointer;}/*!sc*/
# .ezbrTK .label-hint{display:block;position:relative;height:20px;width:20px;}/*!sc*/
# .ezbrTK .label-hint svg{left:50%;position:absolute;top:50%;-webkit-transform:translate(-50%,-50%);-ms-transform:translate(-50%,-50%);transform:translate(-50%,-50%);}/*!sc*/
# @media (hover:hover) and (pointer:fine){.ezbrTK .label-hint:hover{cursor:pointer;}}/*!sc*/
# data-styled.g9[id="Label__StyledLabel-rui__sc-1by3ei1-0"]{content:"enGXSt,ezbrTK,"}/*!sc*/
# .bszylW:not(.focusable),.bszylW.focusable:not(:focus):not(:focus-within){position:absolute !important;width:1px !important;height:1px !important;padding:0 !important;margin:-1px !important;overflow:hidden !important;-webkit-clip:rect(0,0,0,0) !important;clip:rect(0,0,0,0) !important;border:0 !important;white-space:nowrap !important;word-wrap:normal !important;}/*!sc*/
# data-styled.g11[id="VisuallyHiddenstyles__StyledVisuallyHidden-rui__aoql8k-0"]{content:"bszylW,"}/*!sc*/
# .dYVSYa{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# .dYVSYa label{font-size:14px;}/*!sc*/
# data-styled.g12[id="LabelWrapperstyles__StyledLabelWrapper-rui__xiucf9-0"]{content:"dYVSYa,"}/*!sc*/
# .jQGjNK{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:#757575;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;margin-top:4px;}/*!sc*/
# .jQGjNK .helper-text-error-icon{-webkit-align-self:flex-start;-ms-flex-item-align:start;align-self:flex-start;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;margin:0 4px 4px 0;margin-top:2px;}/*!sc*/
# data-styled.g14[id="FormHelperTextstyles__StyledFormHelperText-rui__sc-1rbcmi4-0"]{content:"jQGjNK,"}/*!sc*/
# .gEIIFT{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;background-color:#FFFFFF;border:none;box-shadow:none;border-top:1px solid transparent;border-bottom:1px solid transparent;border-left:1px solid transparent;color:#2B2B2B;cursor:default;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;padding:7px 10px;position:relative;-webkit-transition:border-color 100ms cubic-bezier(0.5,0,0.2,1);transition:border-color 100ms cubic-bezier(0.5,0,0.2,1);z-index:0;border-top-left-radius:8px;border-bottom-left-radius:8px;padding-right:8px;}/*!sc*/
# .isDniz{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;background-color:#FFFFFF;border:none;box-shadow:none;border-top:1px solid transparent;border-bottom:1px solid transparent;border-right:1px solid transparent;color:#2B2B2B;cursor:pointer;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;padding:7px 10px;position:relative;-webkit-transition:border-color 100ms cubic-bezier(0.5,0,0.2,1);transition:border-color 100ms cubic-bezier(0.5,0,0.2,1);z-index:0;border-top-right-radius:8px;border-bottom-right-radius:8px;padding-left:8px;}/*!sc*/
# data-styled.g15[id="InputAddonstyles__StyledInputAddon-rui__sc-1rthqly-0"]{content:"gEIIFT,isDniz,"}/*!sc*/
# .cwHuSN{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;position:relative;}/*!sc*/
# .cwHuSN .InputGroup-rui__hn7d6j-0{border:none;box-shadow:none;border-top:1px solid transparent;border-bottom:1px solid transparent;border-top-left-radius:0;border-bottom-left-radius:0;border-top-right-radius:0;border-bottom-right-radius:0;}/*!sc*/
# .cwHuSN .InputAddonstyles__StyledInputAddon-rui__sc-1rthqly-0{gap:8px;z-index:2;}/*!sc*/
# .cRWzOR{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;position:relative;}/*!sc*/
# .cRWzOR .InputGroup-rui__hn7d6j-0{border:1px solid transparent;box-shadow:none;border-top-left-radius:8px;border-bottom-left-radius:8px;border-top-right-radius:8px;border-bottom-right-radius:8px;}/*!sc*/
# .cRWzOR .InputAddonstyles__StyledInputAddon-rui__sc-1rthqly-0{gap:8px;z-index:2;}/*!sc*/
# data-styled.g16[id="TextInputstyles__StyledWrapper-rui__sih3wv-0"]{content:"cwHuSN,cRWzOR,"}/*!sc*/
# .huxZtp{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;position:relative;border-radius:8px;border:1px solid #757575;}/*!sc*/
# .huxZtp .InputGroup-rui__hn7d6j-0{padding-left:0;padding-right:0;}/*!sc*/
# .huxZtp.outline{border-radius:8px;outline:5px auto Highlight;outline:5px auto -webkit-focus-ring-color;}/*!sc*/
# .huxZtp.outline .InputAddonstyles__StyledInputAddon-rui__sc-1rthqly-0,.huxZtp.outline .InputGroup-rui__hn7d6j-0{border-color:#757575;}/*!sc*/
# .huxZtp.outline input{outline:none;}/*!sc*/
# .hocKaB{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;position:relative;border-radius:8px;border:1px solid #757575;}/*!sc*/
# .hocKaB .InputGroup-rui__hn7d6j-0{padding-left:14px;padding-right:14px;}/*!sc*/
# .hocKaB.outline{border-radius:8px;outline:5px auto Highlight;outline:5px auto -webkit-focus-ring-color;}/*!sc*/
# .hocKaB.outline .InputAddonstyles__StyledInputAddon-rui__sc-1rthqly-0,.hocKaB.outline .InputGroup-rui__hn7d6j-0{border-color:#757575;}/*!sc*/
# .hocKaB.outline input{outline:none;}/*!sc*/
# data-styled.g17[id="TextInputstyles__StyledInputWrapper-rui__sih3wv-1"]{content:"huxZtp,hocKaB,"}/*!sc*/
# .daAHdq{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;background-image:none;cursor:pointer;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;font-weight:500;gap:8px;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;line-height:1;touch-action:manipulation;-webkit-transition:background-color 100ms cubic-bezier(0.5,0,0.2,1),color 100ms cubic-bezier(0.5,0,0.2,1),border-color 100ms cubic-bezier(0.5,0,0.2,1);transition:background-color 100ms cubic-bezier(0.5,0,0.2,1),color 100ms cubic-bezier(0.5,0,0.2,1),border-color 100ms cubic-bezier(0.5,0,0.2,1);-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;vertical-align:middle;font-size:16px;border-radius:40px;border:1px solid transparent;-webkit-text-decoration:none;text-decoration:none;height:36px;border-radius:0;border:0;padding:0;text-align:left;-webkit-text-decoration:underline;text-decoration:underline;color:#2B2B2B;background-color:transparent;border-color:transparent;}/*!sc*/
# .daAHdq.disabled{cursor:not-allowed;}/*!sc*/
# @media (hover:hover) and (pointer:fine){.daAHdq:hover{-webkit-text-decoration:underline;text-decoration:underline;}}/*!sc*/
# .daAHdq:focus{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .daAHdq:focus:not(:focus-visible){outline:none;}/*!sc*/
# @media (hover:hover) and (pointer:fine){.daAHdq:hover{color:#646464;background-color:transparent;border-color:transparent;}}/*!sc*/
# .daAHdq:focus{color:#2B2B2B;}/*!sc*/
# .daAHdq.active{color:#646464;background-color:transparent;border-color:transparent;}/*!sc*/
# .daAHdq.disabled{color:#A0A0A0;background-color:transparent;border-color:transparent;}/*!sc*/
# .fgyveS{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;background-image:none;cursor:pointer;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;font-weight:500;gap:8px;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;line-height:1;touch-action:manipulation;-webkit-transition:background-color 100ms cubic-bezier(0.5,0,0.2,1),color 100ms cubic-bezier(0.5,0,0.2,1),border-color 100ms cubic-bezier(0.5,0,0.2,1);transition:background-color 100ms cubic-bezier(0.5,0,0.2,1),color 100ms cubic-bezier(0.5,0,0.2,1),border-color 100ms cubic-bezier(0.5,0,0.2,1);-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;white-space:nowrap;vertical-align:middle;font-size:16px;border-radius:40px;border:1px solid transparent;-webkit-text-decoration:none;text-decoration:none;height:36px;padding:0 16px;color:#2B2B2B;background-color:#FFFFFF;border-color:#2B2B2B;}/*!sc*/
# .fgyveS.disabled{cursor:not-allowed;}/*!sc*/
# .fgyveS false @media (hover:hover) and (pointer:fine):hover{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .fgyveS:focus{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .fgyveS:focus:not(:focus-visible){outline:none;}/*!sc*/
# @media (hover:hover) and (pointer:fine){.fgyveS:hover{color:#646464;background-color:#F2F2F2;border-color:#646464;}}/*!sc*/
# .fgyveS:focus{color:#2B2B2B;}/*!sc*/
# .fgyveS.active{color:#2B2B2B;background-color:#F2F2F2;border-color:#2B2B2B;}/*!sc*/
# .fgyveS.disabled{color:#A0A0A0;background-color:#F2F2F2;border-color:#A0A0A0;}/*!sc*/
# .kfNLRN{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;background-image:none;cursor:pointer;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;font-weight:500;gap:8px;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;line-height:1;touch-action:manipulation;-webkit-transition:background-color 100ms cubic-bezier(0.5,0,0.2,1),color 100ms cubic-bezier(0.5,0,0.2,1),border-color 100ms cubic-bezier(0.5,0,0.2,1);transition:background-color 100ms cubic-bezier(0.5,0,0.2,1),color 100ms cubic-bezier(0.5,0,0.2,1),border-color 100ms cubic-bezier(0.5,0,0.2,1);-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;white-space:nowrap;vertical-align:middle;font-size:16px;border-radius:40px;border:1px solid transparent;-webkit-text-decoration:none;text-decoration:none;height:48px;padding:0 24px;margin-left:6px;color:#2B2B2B;background-color:#FFFFFF;border-color:#2B2B2B;}/*!sc*/
# .kfNLRN.disabled{cursor:not-allowed;}/*!sc*/
# .kfNLRN false @media (hover:hover) and (pointer:fine):hover{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .kfNLRN:focus{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .kfNLRN:focus:not(:focus-visible){outline:none;}/*!sc*/
# @media (hover:hover) and (pointer:fine){.kfNLRN:hover{color:#646464;background-color:#F2F2F2;border-color:#646464;}}/*!sc*/
# .kfNLRN:focus{color:#2B2B2B;}/*!sc*/
# .kfNLRN.active{color:#2B2B2B;background-color:#F2F2F2;border-color:#2B2B2B;}/*!sc*/
# .kfNLRN.disabled{color:#A0A0A0;background-color:#F2F2F2;border-color:#A0A0A0;}/*!sc*/
# .zxHqB{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;background-image:none;cursor:pointer;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;font-weight:500;gap:8px;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;line-height:1;touch-action:manipulation;-webkit-transition:background-color 100ms cubic-bezier(0.5,0,0.2,1),color 100ms cubic-bezier(0.5,0,0.2,1),border-color 100ms cubic-bezier(0.5,0,0.2,1);transition:background-color 100ms cubic-bezier(0.5,0,0.2,1),color 100ms cubic-bezier(0.5,0,0.2,1),border-color 100ms cubic-bezier(0.5,0,0.2,1);-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;vertical-align:inherit;font-size:inherit;height:auto;-webkit-text-decoration:underline;text-decoration:underline;border-radius:0;border:0;padding:0;text-align:left;-webkit-text-decoration:underline;text-decoration:underline;color:#2B2B2B;background-color:transparent;border-color:transparent;}/*!sc*/
# .zxHqB.disabled{cursor:not-allowed;}/*!sc*/
# @media (hover:hover) and (pointer:fine){.zxHqB:hover{-webkit-text-decoration:underline;text-decoration:underline;}}/*!sc*/
# .zxHqB:focus{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .zxHqB:focus:not(:focus-visible){outline:none;}/*!sc*/
# @media (hover:hover) and (pointer:fine){.zxHqB:hover{color:#646464;background-color:transparent;border-color:transparent;}}/*!sc*/
# .zxHqB:focus{color:#2B2B2B;}/*!sc*/
# .zxHqB.active{color:#646464;background-color:transparent;border-color:transparent;}/*!sc*/
# .zxHqB.disabled{color:#A0A0A0;background-color:transparent;border-color:transparent;}/*!sc*/
# .gmefcD{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;background-image:none;cursor:pointer;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;font-weight:500;gap:8px;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;line-height:1;touch-action:manipulation;-webkit-transition:background-color 100ms cubic-bezier(0.5,0,0.2,1),color 100ms cubic-bezier(0.5,0,0.2,1),border-color 100ms cubic-bezier(0.5,0,0.2,1);transition:background-color 100ms cubic-bezier(0.5,0,0.2,1),color 100ms cubic-bezier(0.5,0,0.2,1),border-color 100ms cubic-bezier(0.5,0,0.2,1);-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;vertical-align:middle;font-size:16px;border-radius:40px;border:1px solid transparent;-webkit-text-decoration:none;text-decoration:none;height:48px;border-radius:0;border:0;padding:0;text-align:left;-webkit-text-decoration:underline;text-decoration:underline;color:#2B2B2B;background-color:transparent;border-color:transparent;}/*!sc*/
# .gmefcD.disabled{cursor:not-allowed;}/*!sc*/
# @media (hover:hover) and (pointer:fine){.gmefcD:hover{-webkit-text-decoration:underline;text-decoration:underline;}}/*!sc*/
# .gmefcD:focus{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .gmefcD:focus:not(:focus-visible){outline:none;}/*!sc*/
# @media (hover:hover) and (pointer:fine){.gmefcD:hover{color:#646464;background-color:transparent;border-color:transparent;}}/*!sc*/
# .gmefcD:focus{color:#2B2B2B;}/*!sc*/
# .gmefcD.active{color:#646464;background-color:transparent;border-color:transparent;}/*!sc*/
# .gmefcD.disabled{color:#A0A0A0;background-color:transparent;border-color:transparent;}/*!sc*/
# .edsdcm{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;background-image:none;cursor:pointer;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;font-weight:500;gap:8px;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;line-height:1;touch-action:manipulation;-webkit-transition:background-color 100ms cubic-bezier(0.5,0,0.2,1),color 100ms cubic-bezier(0.5,0,0.2,1),border-color 100ms cubic-bezier(0.5,0,0.2,1);transition:background-color 100ms cubic-bezier(0.5,0,0.2,1),color 100ms cubic-bezier(0.5,0,0.2,1),border-color 100ms cubic-bezier(0.5,0,0.2,1);-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;white-space:nowrap;vertical-align:middle;font-size:16px;border-radius:40px;border:1px solid transparent;-webkit-text-decoration:none;text-decoration:none;height:48px;padding:0 24px;color:#2B2B2B;background-color:#FFFFFF;border-color:#2B2B2B;}/*!sc*/
# .edsdcm.disabled{cursor:not-allowed;}/*!sc*/
# .edsdcm false @media (hover:hover) and (pointer:fine):hover{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .edsdcm:focus{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .edsdcm:focus:not(:focus-visible){outline:none;}/*!sc*/
# @media (hover:hover) and (pointer:fine){.edsdcm:hover{color:#646464;background-color:#F2F2F2;border-color:#646464;}}/*!sc*/
# .edsdcm:focus{color:#2B2B2B;}/*!sc*/
# .edsdcm.active{color:#2B2B2B;background-color:#F2F2F2;border-color:#2B2B2B;}/*!sc*/
# .edsdcm.disabled{color:#A0A0A0;background-color:#F2F2F2;border-color:#A0A0A0;}/*!sc*/
# .jvTDEP{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;background-image:none;cursor:pointer;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;font-weight:500;gap:8px;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;line-height:1;touch-action:manipulation;-webkit-transition:background-color 100ms cubic-bezier(0.5,0,0.2,1),color 100ms cubic-bezier(0.5,0,0.2,1),border-color 100ms cubic-bezier(0.5,0,0.2,1);transition:background-color 100ms cubic-bezier(0.5,0,0.2,1),color 100ms cubic-bezier(0.5,0,0.2,1),border-color 100ms cubic-bezier(0.5,0,0.2,1);-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;white-space:nowrap;vertical-align:middle;font-size:16px;border-radius:40px;border:1px solid transparent;-webkit-text-decoration:none;text-decoration:none;height:48px;padding:0 24px;color:#2B2B2B;background-color:#FFFFFF;border-color:#2B2B2B;box-shadow:0px 2px 8px rgba(0,0,0,0.16);}/*!sc*/
# .jvTDEP.disabled{cursor:not-allowed;}/*!sc*/
# .jvTDEP false @media (hover:hover) and (pointer:fine):hover{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .jvTDEP:focus{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .jvTDEP:focus:not(:focus-visible){outline:none;}/*!sc*/
# @media (hover:hover) and (pointer:fine){.jvTDEP:hover{color:#2B2B2B;background-color:#F2F2F2;border-color:#2B2B2B;box-shadow:0px 2px 8px rgba(0,0,0,0.16);}}/*!sc*/
# .jvTDEP:focus{color:#2B2B2B;}/*!sc*/
# .jvTDEP.active{color:#2B2B2B;background-color:#F2F2F2;border-color:#2B2B2B;}/*!sc*/
# .jvTDEP.disabled{color:#A0A0A0;background-color:#F2F2F2;border-color:#A0A0A0;box-shadow:none;}/*!sc*/
# .glggPf{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;background-image:none;cursor:pointer;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;font-weight:500;gap:8px;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;line-height:1;touch-action:manipulation;-webkit-transition:background-color 100ms cubic-bezier(0.5,0,0.2,1),color 100ms cubic-bezier(0.5,0,0.2,1),border-color 100ms cubic-bezier(0.5,0,0.2,1);transition:background-color 100ms cubic-bezier(0.5,0,0.2,1),color 100ms cubic-bezier(0.5,0,0.2,1),border-color 100ms cubic-bezier(0.5,0,0.2,1);-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;vertical-align:middle;font-size:16px;border-radius:40px;border:1px solid transparent;-webkit-text-decoration:none;text-decoration:none;height:48px;border-radius:0;border:0;padding:0;text-align:left;-webkit-text-decoration:none;text-decoration:none;color:#FFFFFF;background-color:transparent;border-color:transparent;}/*!sc*/
# .glggPf.disabled{cursor:not-allowed;}/*!sc*/
# @media (hover:hover) and (pointer:fine){.glggPf:hover{-webkit-text-decoration:underline;text-decoration:underline;}}/*!sc*/
# .glggPf:focus{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .glggPf:focus:not(:focus-visible){outline:none;}/*!sc*/
# @media (hover:hover) and (pointer:fine){.glggPf:hover{color:#F2F2F2;background-color:transparent;border-color:transparent;}}/*!sc*/
# .glggPf:focus{color:#FFFFFF;}/*!sc*/
# .glggPf.active{color:#F2F2F2;background-color:transparent;border-color:transparent;}/*!sc*/
# .glggPf.disabled{color:#A0A0A0;background-color:transparent;border-color:transparent;}/*!sc*/
# .hlouAn{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;background-image:none;cursor:pointer;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;font-weight:500;gap:8px;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;line-height:1;touch-action:manipulation;-webkit-transition:background-color 100ms cubic-bezier(0.5,0,0.2,1),color 100ms cubic-bezier(0.5,0,0.2,1),border-color 100ms cubic-bezier(0.5,0,0.2,1);transition:background-color 100ms cubic-bezier(0.5,0,0.2,1),color 100ms cubic-bezier(0.5,0,0.2,1),border-color 100ms cubic-bezier(0.5,0,0.2,1);-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;vertical-align:middle;font-size:16px;border-radius:40px;border:1px solid transparent;-webkit-text-decoration:none;text-decoration:none;height:48px;border-radius:0;border:0;padding:0;text-align:left;-webkit-text-decoration:underline;text-decoration:underline;color:#FFFFFF;background-color:transparent;border-color:transparent;}/*!sc*/
# .hlouAn.disabled{cursor:not-allowed;}/*!sc*/
# @media (hover:hover) and (pointer:fine){.hlouAn:hover{-webkit-text-decoration:underline;text-decoration:underline;}}/*!sc*/
# .hlouAn:focus{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .hlouAn:focus:not(:focus-visible){outline:none;}/*!sc*/
# @media (hover:hover) and (pointer:fine){.hlouAn:hover{color:#F2F2F2;background-color:transparent;border-color:transparent;}}/*!sc*/
# .hlouAn:focus{color:#FFFFFF;}/*!sc*/
# .hlouAn.active{color:#F2F2F2;background-color:transparent;border-color:transparent;}/*!sc*/
# .hlouAn.disabled{color:#A0A0A0;background-color:transparent;border-color:transparent;}/*!sc*/
# .iceotV{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;background-image:none;cursor:pointer;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;font-weight:500;gap:8px;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;line-height:1;touch-action:manipulation;-webkit-transition:background-color 100ms cubic-bezier(0.5,0,0.2,1),color 100ms cubic-bezier(0.5,0,0.2,1),border-color 100ms cubic-bezier(0.5,0,0.2,1);transition:background-color 100ms cubic-bezier(0.5,0,0.2,1),color 100ms cubic-bezier(0.5,0,0.2,1),border-color 100ms cubic-bezier(0.5,0,0.2,1);-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;vertical-align:inherit;font-size:inherit;height:auto;-webkit-text-decoration:underline;text-decoration:underline;border-radius:0;border:0;padding:0;text-align:left;-webkit-text-decoration:underline;text-decoration:underline;color:#FFFFFF;background-color:transparent;border-color:transparent;}/*!sc*/
# .iceotV.disabled{cursor:not-allowed;}/*!sc*/
# @media (hover:hover) and (pointer:fine){.iceotV:hover{-webkit-text-decoration:underline;text-decoration:underline;}}/*!sc*/
# .iceotV:focus{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .iceotV:focus:not(:focus-visible){outline:none;}/*!sc*/
# @media (hover:hover) and (pointer:fine){.iceotV:hover{color:#F2F2F2;background-color:transparent;border-color:transparent;}}/*!sc*/
# .iceotV:focus{color:#FFFFFF;}/*!sc*/
# .iceotV.active{color:#F2F2F2;background-color:transparent;border-color:transparent;}/*!sc*/
# .iceotV.disabled{color:#A0A0A0;background-color:transparent;border-color:transparent;}/*!sc*/
# data-styled.g19[id="base__StyledAnchor-rui__ermeke-0"]{content:"daAHdq,fgyveS,kfNLRN,zxHqB,gmefcD,edsdcm,jvTDEP,glggPf,hlouAn,iceotV,"}/*!sc*/
# .hxAKlP{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;background-image:none;cursor:pointer;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;font-weight:500;gap:8px;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;line-height:1;touch-action:manipulation;-webkit-transition:background-color 100ms cubic-bezier(0.5,0,0.2,1),color 100ms cubic-bezier(0.5,0,0.2,1),border-color 100ms cubic-bezier(0.5,0,0.2,1);transition:background-color 100ms cubic-bezier(0.5,0,0.2,1),color 100ms cubic-bezier(0.5,0,0.2,1),border-color 100ms cubic-bezier(0.5,0,0.2,1);-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;vertical-align:inherit;font-size:inherit;height:auto;-webkit-text-decoration:underline;text-decoration:underline;border-radius:0;border:0;padding:0;text-align:left;-webkit-text-decoration:underline;text-decoration:underline;color:#2B2B2B;background-color:transparent;border-color:transparent;}/*!sc*/
# .hxAKlP.disabled{cursor:not-allowed;}/*!sc*/
# @media (hover:hover) and (pointer:fine){.hxAKlP:hover{-webkit-text-decoration:underline;text-decoration:underline;}}/*!sc*/
# .hxAKlP:focus{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .hxAKlP:focus:not(:focus-visible){outline:none;}/*!sc*/
# @media (hover:hover) and (pointer:fine){.hxAKlP:hover{color:#646464;background-color:transparent;border-color:transparent;}}/*!sc*/
# .hxAKlP:focus{color:#2B2B2B;}/*!sc*/
# .hxAKlP.active{color:#646464;background-color:transparent;border-color:transparent;}/*!sc*/
# .hxAKlP.disabled{color:#A0A0A0;background-color:transparent;border-color:transparent;}/*!sc*/
# .hGDzwI{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;background-image:none;cursor:pointer;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;font-weight:500;gap:8px;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;line-height:1;touch-action:manipulation;-webkit-transition:background-color 100ms cubic-bezier(0.5,0,0.2,1),color 100ms cubic-bezier(0.5,0,0.2,1),border-color 100ms cubic-bezier(0.5,0,0.2,1);transition:background-color 100ms cubic-bezier(0.5,0,0.2,1),color 100ms cubic-bezier(0.5,0,0.2,1),border-color 100ms cubic-bezier(0.5,0,0.2,1);-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;white-space:nowrap;vertical-align:middle;font-size:16px;border-radius:40px;border:1px solid transparent;-webkit-text-decoration:none;text-decoration:none;height:48px;padding:0 24px;color:#2B2B2B;background-color:#FFFFFF;border-color:#2B2B2B;}/*!sc*/
# .hGDzwI.disabled{cursor:not-allowed;}/*!sc*/
# .hGDzwI false @media (hover:hover) and (pointer:fine):hover{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .hGDzwI:focus{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .hGDzwI:focus:not(:focus-visible){outline:none;}/*!sc*/
# @media (hover:hover) and (pointer:fine){.hGDzwI:hover{color:#646464;background-color:#F2F2F2;border-color:#646464;}}/*!sc*/
# .hGDzwI:focus{color:#2B2B2B;}/*!sc*/
# .hGDzwI.active{color:#2B2B2B;background-color:#F2F2F2;border-color:#2B2B2B;}/*!sc*/
# .hGDzwI.disabled{color:#A0A0A0;background-color:#F2F2F2;border-color:#A0A0A0;}/*!sc*/
# .ffYpfM{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;background-image:none;cursor:pointer;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;font-weight:500;gap:8px;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;line-height:1;touch-action:manipulation;-webkit-transition:background-color 100ms cubic-bezier(0.5,0,0.2,1),color 100ms cubic-bezier(0.5,0,0.2,1),border-color 100ms cubic-bezier(0.5,0,0.2,1);transition:background-color 100ms cubic-bezier(0.5,0,0.2,1),color 100ms cubic-bezier(0.5,0,0.2,1),border-color 100ms cubic-bezier(0.5,0,0.2,1);-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;white-space:nowrap;vertical-align:middle;font-size:16px;border-radius:40px;border:1px solid transparent;-webkit-text-decoration:none;text-decoration:none;height:48px;padding:0 24px;color:#FFFFFF;background-color:#2B2B2B;border-color:#2B2B2B;}/*!sc*/
# .ffYpfM.disabled{cursor:not-allowed;}/*!sc*/
# .ffYpfM false @media (hover:hover) and (pointer:fine):hover{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .ffYpfM:focus{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .ffYpfM:focus:not(:focus-visible){outline:none;}/*!sc*/
# @media (hover:hover) and (pointer:fine){.ffYpfM:hover{color:#FFFFFF;background-color:#646464;border-color:#646464;}}/*!sc*/
# .ffYpfM:focus{color:#FFFFFF;}/*!sc*/
# .ffYpfM.active{color:#FFFFFF;background-color:#646464;border-color:#646464;}/*!sc*/
# .ffYpfM.disabled{color:#A0A0A0;background-color:#F2F2F2;border-color:#A0A0A0;}/*!sc*/
# .jSAjYL{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;background-image:none;cursor:pointer;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;font-weight:500;gap:8px;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;line-height:1;touch-action:manipulation;-webkit-transition:background-color 100ms cubic-bezier(0.5,0,0.2,1),color 100ms cubic-bezier(0.5,0,0.2,1),border-color 100ms cubic-bezier(0.5,0,0.2,1);transition:background-color 100ms cubic-bezier(0.5,0,0.2,1),color 100ms cubic-bezier(0.5,0,0.2,1),border-color 100ms cubic-bezier(0.5,0,0.2,1);-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;white-space:nowrap;vertical-align:middle;font-size:16px;border-radius:40px;border:1px solid transparent;-webkit-text-decoration:none;text-decoration:none;height:48px;padding:0 24px;width:100%;color:#2B2B2B;background-color:#FFFFFF;border-color:#2B2B2B;}/*!sc*/
# .jSAjYL.disabled{cursor:not-allowed;}/*!sc*/
# .jSAjYL false @media (hover:hover) and (pointer:fine):hover{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .jSAjYL:focus{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .jSAjYL:focus:not(:focus-visible){outline:none;}/*!sc*/
# @media (hover:hover) and (pointer:fine){.jSAjYL:hover{color:#646464;background-color:#F2F2F2;border-color:#646464;}}/*!sc*/
# .jSAjYL:focus{color:#2B2B2B;}/*!sc*/
# .jSAjYL.active{color:#2B2B2B;background-color:#F2F2F2;border-color:#2B2B2B;}/*!sc*/
# .jSAjYL.disabled{color:#A0A0A0;background-color:#F2F2F2;border-color:#A0A0A0;}/*!sc*/
# .btPtDl{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;background-image:none;cursor:pointer;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;font-weight:500;gap:8px;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;line-height:1;touch-action:manipulation;-webkit-transition:background-color 100ms cubic-bezier(0.5,0,0.2,1),color 100ms cubic-bezier(0.5,0,0.2,1),border-color 100ms cubic-bezier(0.5,0,0.2,1);transition:background-color 100ms cubic-bezier(0.5,0,0.2,1),color 100ms cubic-bezier(0.5,0,0.2,1),border-color 100ms cubic-bezier(0.5,0,0.2,1);-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;white-space:nowrap;vertical-align:middle;font-size:16px;border-radius:40px;border:1px solid transparent;-webkit-text-decoration:none;text-decoration:none;height:48px;padding:0 24px;color:#2B2B2B;background-color:#FFFFFF;border-color:#2B2B2B;box-shadow:0px 2px 8px rgba(0,0,0,0.16);}/*!sc*/
# .btPtDl.disabled{cursor:not-allowed;}/*!sc*/
# .btPtDl false @media (hover:hover) and (pointer:fine):hover{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .btPtDl:focus{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .btPtDl:focus:not(:focus-visible){outline:none;}/*!sc*/
# @media (hover:hover) and (pointer:fine){.btPtDl:hover{color:#2B2B2B;background-color:#F2F2F2;border-color:#2B2B2B;box-shadow:0px 2px 8px rgba(0,0,0,0.16);}}/*!sc*/
# .btPtDl:focus{color:#2B2B2B;}/*!sc*/
# .btPtDl.active{color:#2B2B2B;background-color:#F2F2F2;border-color:#2B2B2B;}/*!sc*/
# .btPtDl.disabled{color:#A0A0A0;background-color:#F2F2F2;border-color:#A0A0A0;box-shadow:none;}/*!sc*/
# ...
# @media (hover:hover) and (pointer:fine){.ozaAl:hover{color:#FFFFFF;-webkit-text-decoration:none;text-decoration:none;}}/*!sc*/
# .ozaAl:focus:not(:focus-visible){outline:none;}/*!sc*/
# data-styled.g297[id="HorizontalTileSliderstyles__StyledTile-rui__l1he7-1"]{content:"ozaAl,"}/*!sc*/
# .eiXzCt > h2{margin-bottom:8px;}/*!sc*/
# .eiXzCt .search-summary-control-link{margin-top:16px;margin-right:auto;}/*!sc*/
# .eiXzCt .search-summary-collapse h3{font-size:16px;margin:16px 0;}/*!sc*/
# .eiXzCt .summary-link-list{-webkit-column-count:1;column-count:1;padding-left:0;list-style:none;}/*!sc*/
# .eiXzCt .summary-link-list li{margin-bottom:8px;}/*!sc*/
# @media (min-width:480px){.eiXzCt .summary-link-list{-webkit-column-count:2;column-count:2;}}/*!sc*/
# @media (min-width:768px){.eiXzCt .summary-link-list{-webkit-column-count:3;column-count:3;}}/*!sc*/
# data-styled.g298[id="SearchSummaryWidgetstyles__StyledSearchSummaryWidget-rui__sc-56k7qk-0"]{content:"eiXzCt,"}/*!sc*/
# .ixcScZ .pre-approved-widget-image-wrapper{padding-bottom:50%;overflow:hidden;position:relative;margin:0 0 16px;}/*!sc*/
# .ixcScZ .pre-approved-widget-image-wrapper img{position:absolute;top:50%;width:100%;-webkit-transform:translate(0,-50%);-ms-transform:translate(0,-50%);transform:translate(0,-50%);}/*!sc*/
# data-styled.g299[id="PreApprovedWidgetstyles__StyledPreApprovedWidget-rui__vo2wch-0"]{content:"ixcScZ,"}/*!sc*/
# .jLrZsN{text-align:center;width:100%;display:none;}/*!sc*/
# @media (min-width:768px){.jLrZsN{min-height:90px;margin-top:16px;margin-bottom:16px;display:block;}}/*!sc*/
# .poPni{text-align:center;width:100%;display:none;}/*!sc*/
# @media (min-width:768px){.poPni{min-height:90px;margin-top:16px;margin-bottom:16px;display:none;}}/*!sc*/
# data-styled.g302[id="sc-AxjAm"]{content:"jLrZsN,poPni,"}/*!sc*/
# @media (min-width:768px){.bjYcLx{display:none;}}/*!sc*/
# @supports (-webkit-touch-callout:none){.bjYcLx[data-ios-chrome='0']{display:none;}}/*!sc*/
# data-styled.g303[id="styles__StyledMobileBanner-sc-1mjf4fr-0"]{content:"bjYcLx,"}/*!sc*/
# .fbBRoL{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;min-height:100vh;}/*!sc*/
# .fbBRoL .main-container{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-flex:1 0 auto;-ms-flex:1 0 auto;flex:1 0 auto;}/*!sc*/
# .fbBRoL .footer{-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;}/*!sc*/
# data-styled.g304[id="styles__StyledAppShell-sc-1a4hn7f-0"]{content:"fbBRoL,"}/*!sc*/
# .bwVfWB{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;background-color:#1E61D9;border-radius:50%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;height:40px;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;width:40px;}/*!sc*/
# data-styled.g1507[id="GreatSchoolRatingstyles__StyledGreatSchoolRating-rlp__sc-1xs8bmk-0"]{content:"bwVfWB,"}/*!sc*/
# .RjNYR{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;}/*!sc*/
# .RjNYR .widget-wrapper{padding:16px;-webkit-flex:0 1 auto;-ms-flex:0 1 auto;flex:0 1 auto;width:calc(25% - 16px);}/*!sc*/
# @media (min-width:768px) and (max-width:995px){.RjNYR .widget-wrapper{width:calc(50% - 16px);}}/*!sc*/
# @media (max-width:767px){.RjNYR .widget-wrapper{width:100%;}}/*!sc*/
# .RjNYR .widget-label{min-height:50px;}/*!sc*/
# .RjNYR .price-string{margin:0;}/*!sc*/
# .RjNYR .list-container{list-style:none;padding:0;margin:0;overflow-y:auto;max-height:136px;}/*!sc*/
# .RjNYR .list-container li{padding:8px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;}/*!sc*/
# .RjNYR .mobile-list-container{list-style:none;padding:0;margin:0;}/*!sc*/
# .RjNYR .mobile-list-container li{padding:8px 0;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;}/*!sc*/
# .RjNYR .see-more-less{margin-top:auto;-webkit-box-pack:left;-webkit-justify-content:left;-ms-flex-pack:left;justify-content:left;}/*!sc*/
# data-styled.g1508[id="HomeValuesWidgetstyles__StyledHomeValuesWidget-rlp__sc-18sicuv-0"]{content:"RjNYR,"}/*!sc*/
# .jESfin .data-wrapper{padding-bottom:16px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:flex-start;-webkit-box-align:flex-start;-ms-flex-align:flex-start;align-items:flex-start;}/*!sc*/
# .jESfin .data-wrapper strong{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;margin-left:8px;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;}/*!sc*/
# .jESfin .data-wrapper svg{-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;}/*!sc*/
# .jESfin .data-wrapper .arrow{margin-left:8px;margin-right:-4px;}/*!sc*/
# .jESfin .title{font-size:16px;margin-bottom:16px;height:auto;vertical-align:inherit;white-space:normal;text-align:left;}/*!sc*/
# data-styled.g1521[id="MarketTrendsstyles__StyledMarketTrends-rlp__sc-d3jr56-0"]{content:"jESfin,"}/*!sc*/
# .iGSDEp [role='tabpanel']{padding-bottom:0;}/*!sc*/
# .iGSDEp .school-row{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# .iGSDEp .school-row > .school-col{-webkit-flex:0 0 33.3333%;-ms-flex:0 0 33.3333%;flex:0 0 33.3333%;}/*!sc*/
# @media (max-width:767px){.iGSDEp .school-row > .school-col{-webkit-flex:0 1 auto;-ms-flex:0 1 auto;flex:0 1 auto;border-bottom:1px solid #CACACA;}}/*!sc*/
# @media (max-width:767px){.iGSDEp .school-list .school-row:last-child .school-col:last-child{border-bottom:0;}}/*!sc*/
# .iGSDEp .school-item{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;padding:8px 0;margin:0 8px;}/*!sc*/
# .iGSDEp .school-item .school-item-list{margin:0 0 0 16px;padding:0;list-style-type:none;}/*!sc*/
# .iGSDEp .school-item > div:first-child{-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;}/*!sc*/
# .iGSDEp .title{padding-bottom:8px;}/*!sc*/
# .iGSDEp .see-more-less{padding:8px 0 0;}/*!sc*/
# .iGSDEp .disclaimer-text{padding:8px 0 0;}/*!sc*/
# .iGSDEp .icon{padding-top:8px;}/*!sc*/
# data-styled.g1527[id="SchoolDataWithTabsstyles__StyledSchoolDataWithTabs-rlp__sc-10gyfo0-0"]{content:"iGSDEp,"}/*!sc*/
# .ReactModal__Body--open{overflow:hidden;}/*!sc*/
# data-styled.g1935[id="sc-global-WcUdU1"]{content:"sc-global-WcUdU1,"}/*!sc*/
# .ReactModal__Body--open{overflow:hidden;}/*!sc*/
# data-styled.g1936[id="sc-global-WcUdU2"]{content:"sc-global-WcUdU2,"}/*!sc*/
# .ReactModal__Body--open{overflow:hidden;}/*!sc*/
# data-styled.g1937[id="sc-global-WcUdU3"]{content:"sc-global-WcUdU3,"}/*!sc*/
# @-webkit-keyframes fEWCgj{0%{-webkit-transform:rotate(0deg);-ms-transform:rotate(0deg);transform:rotate(0deg);}100%{-webkit-transform:rotate(360deg);-ms-transform:rotate(360deg);transform:rotate(360deg);}}/*!sc*/
# @keyframes fEWCgj{0%{-webkit-transform:rotate(0deg);-ms-transform:rotate(0deg);transform:rotate(0deg);}100%{-webkit-transform:rotate(360deg);-ms-transform:rotate(360deg);transform:rotate(360deg);}}/*!sc*/
# data-styled.g1938[id="sc-keyframes-fEWCgj"]{content:"fEWCgj,"}/*!sc*/
# </style></head><body><div data-reactroot="" id="__next"><div class="styles__StyledAppShell-sc-1a4hn7f-0 fbBRoL"><div class="main-container"><div class="sc-AxjAm jLrZsN ad-wrapper lb1-ad" id="lb1_container_srp" visibility="block"><div class="ads" data-testid="div-gpt-ad-LB1-SRP" id="div-gpt-ad-LB1-SRP"></div></div><div class="sc-AxjAm poPni ad-wrapper lb1-ad" id="lb1_container" visibility="none"><div class="ads" data-testid="div-gpt-ad-LB1" id="div-gpt-ad-LB1"></div></div><div class="MobileBannerstyles__StyledMobileBanner-rui__sc-1udwx2o-0 brcRvz styles__StyledMobileBanner-sc-1mjf4fr-0 bjYcLx" data-ios-chrome="0"><button aria-label="Close" class="CloseButtonstyles__StyledCloseButton-rui__h4a9jf-0 TOPhc close-icon" data-testid="close-button" reversed=""></button><svg aria-hidden="true" class="app-icon" data-testid="core-icon" focusable="false" style="display:inline-block;width:1em;height:1em;font-size:40px;color:#FFFFFF;fill:currentColor" viewbox="0 0 24 24"><path clip-rule="evenodd" d="M12.01 2.5 22 12.712h-3.047v9.163h-13.9v-9.163H2L12.01 2.5Zm2.618 7.13c.508 0 .93.144 1.193.406.25.276.37.604.363 1.01 0 .597-.376 1.194-1.088 1.194-.719 0-.97-.446-1.147-.866-.152-.367-.29-.597-.502-.597-.553 0-1.404 1.253-1.622 2.814-.02.25-.046.82-.046 1.41v1.955c0 1.115.119 1.574.31 1.98.132.243.257.375.402.427.198.085.343.111.541.131l.086.007v.275H8.264v-.275l.093-.007c.224-.026.422-.079.58-.15.284-.145.422-.276.554-.703.072-.439.086-1.095.086-1.574v-4.69c0-.354 0-1.18-.066-1.462a.825.825 0 0 0-.37-.57c-.23-.165-.48-.19-.745-.21l-.085-.007v-.275h3.25c.172 0 .251.118.251.23a71.547 71.547 0 0 1-.024 1.212l-.015.729c.342-.919.758-1.391 1.12-1.739l.007-.006c.363-.302.89-.65 1.728-.65Z" fill="#fff" fill-rule="evenodd"></path></svg><div class="headlines"><div class="base__StyledType-rui__sc-108xfm0-0 hhZQzR title">Realtor.com® Real Estate App</div><span class="reviews"><div aria-label="4.5 out of 5 stars" class="StarRatingsstyles__StyledStarRatings-rui__sc-1ftq0cx-0 jzPUG ratings" role="img"><svg aria-hidden="true" data-testid="icon-star-filled" focusable="false" style="display:inline-block;width:1em;height:1em;font-size:16px;color:#F4B630;fill:currentColor" viewbox="0 0 24 24"><path d="m14.642 4.07 1.467 2.973 3.281.477c2.417.35 3.382 3.32 1.633 5.025l-2.374 2.314.56 3.268c.413 2.407-2.113 4.242-4.275 3.106L12 19.69l-2.934 1.543c-2.162 1.136-4.688-.7-4.275-3.106l.56-3.268-2.374-2.314C1.228 10.841 2.193 7.871 4.61 7.52l3.28-.477L9.359 4.07c1.08-2.19 4.203-2.19 5.284 0Z"></path></svg><svg aria-hidden="true" data-testid="icon-star-filled" focusable="false" style="display:inline-block;width:1em;height:1em;font-size:16px;color:#F4B630;fill:currentColor" viewbox="0 0 24 24"><path d="m14.642 4.07 1.467 2.973 3.281.477c2.417.35 3.382 3.32 1.633 5.025l-2.374 2.314.56 3.268c.413 2.407-2.113 4.242-4.275 3.106L12 19.69l-2.934 1.543c-2.162 1.136-4.688-.7-4.275-3.106l.56-3.268-2.374-2.314C1.228 10.841 2.193 7.871 4.61 7.52l3.28-.477L9.359 4.07c1.08-2.19 4.203-2.19 5.284 0Z"></path></svg><svg aria-hidden="true" data-testid="icon-star-filled" focusable="false" style="display:inline-block;width:1em;height:1em;font-size:16px;color:#F4B630;fill:currentColor" viewbox="0 0 24 24"><path d="m14.642 4.07 1.467 2.973 3.281.477c2.417.35 3.382 3.32 1.633 5.025l-2.374 2.314.56 3.268c.413 2.407-2.113 4.242-4.275 3.106L12 19.69l-2.934 1.543c-2.162 1.136-4.688-.7-4.275-3.106l.56-3.268-2.374-2.314C1.228 10.841 2.193 7.871 4.61 7.52l3.28-.477L9.359 4.07c1.08-2.19 4.203-2.19 5.284 0Z"></path></svg><svg aria-hidden="true" data-testid="icon-star-filled" focusable="false" style="display:inline-block;width:1em;height:1em;font-size:16px;color:#F4B630;fill:currentColor" viewbox="0 0 24 24"><path d="m14.642 4.07 1.467 2.973 3.281.477c2.417.35 3.382 3.32 1.633 5.025l-2.374 2.314.56 3.268c.413 2.407-2.113 4.242-4.275 3.106L12 19.69l-2.934 1.543c-2.162 1.136-4.688-.7-4.275-3.106l.56-3.268-2.374-2.314C1.228 10.841 2.193 7.871 4.61 7.52l3.28-.477L9.359 4.07c1.08-2.19 4.203-2.19 5.284 0Z"></p ...
#           window.__OPTIMIZELY_CACHE_ENTRIES__={"EXP_GLOBAL_HOLDOUT-undefined-{}":{"isEnabled":false,"variables":{"trackId":"GH24Q4"}},"ccx_apollo_client_ldp-{}":true,"SRP_RERANK_EXPERIMENT-undefined-{}":{"isEnabled":false,"variables":{"EXPERIMENT_KEY":"PLATFORMS_SRP_FRACTAL_V2_BOOSTED_1123_FT","FEATURE_KEY":"PLATFORMS_SRP_FRACTAL_V2_BOOSTED_1123"}},"PLATFORMS_SRP_FRACTAL_V2_BOOSTED_1123-PLATFORMS_SRP_FRACTAL_V2_BOOSTED_1123_FT-{}":{"isEnabled":true,"variables":{"Bucket_Values":{"sort":"fractal_v2.1.4"}},"variation":"V4"},"PLATFORMS_SRP_FRACTAL_V2_BOOSTED_1123-Bucket_Values-json-{}":{"sort":"fractal_v2.1.4"},"ccx_map_tiger_lvt-CCX_MAP_TIGER_LVT-{}":{"isEnabled":false,"variables":{"Variation":""},"variation":null},"ccx_map_tiger_lvt_mweb-CCX_MAP_TIGER_LVT_MWEB-{}":{"isEnabled":false,"variables":{"Variation":""},"variation":null},"ccx_map_tiger_mvt-CCX_MAP_TIGER_MVT-{}":{"isEnabled":false,"variables":{"Variation":""},"variation":null},"CCX_HP_SAVESEARCH_CONV_FEATURE-CCX_HP_SAVESEARCH_CONV_TEST_202306-{}":{"isEnabled":false,"variables":{},"variation":null},"FOR_SALE_SRP_TWO_TAP-FOR_SALE_SRP_TWO_TAP_202211-{}":{"isEnabled":false,"variables":{"Variation":"C"},"variation":null},"CCX_SRP_MONTHLY_PAYMENT-CCX_SRP_MONTHLY_PAYMENT_202311-{}":{"isEnabled":false,"variables":{"Variation":"C"},"variation":null},"WBS2311_FILTERCNTRL-WBS2311_FILTERCNTRL-{}":{"isEnabled":true,"variables":{"Variation":"V1"},"variation":"V1"},"RN_SRP_SHARE_RESULTS-RN_SRP_SHARE_RESULTS_202302-{}":{"isEnabled":false,"variables":{"Variation":"C"},"variation":null},"MEDIA_SRP_NEW_CONSTRUCTION-MEDIA_SRP_NEW_CONSTRUCTION_202303-{}":{"isEnabled":true,"variables":{"Variation":"C"},"variation":"C"},"MEDIA_RENTAL_SRP_GOOGLE_ADSENSE-MEDIA_RENTAL_SRP_GOOGLE_ADSENSE_202304-{}":{"isEnabled":false,"variables":{"Variation":""},"variation":null},"cube_intersection_observer_mobile-cube_intersection_observer_mobile_test-{}":{"isEnabled":false,"variables":{},"variation":null},"MEDIA_SRP_TILE3_VIDEO_AD-MEDIA_SRP_TILE3_VIDEO_AD_202309-{}":{"isEnabled":true,"variables":{"Variation":"V2"},"variation":"V2"},"cube_intersection_observer_desktop-cube_intersection_observer_desktop_test-{}":{"isEnabled":false,"variables":{},"variation":null},"ads_tiger_fetch_priority-ads_tiger_fetch_priority_test-{}":{"isEnabled":false,"variables":{},"variation":null},"CX_SRP_LDP_QUICKVIEW_4-CX_SRP_LDP_QUICKVIEW_4_202309-{}":{"isEnabled":false,"variables":{"Variation":""},"variation":null},"CCX_DESKTOP_SRP_NEWTAB-CCX_DESKTOP_SRP_NEWTAB_202309-{}":{"isEnabled":false,"variables":{"Variation":""},"variation":null},"srp_mweb_flat_card-SRP_MWEB_FLAT_CARD_202309-{}":{"isEnabled":false,"variables":{"Variation":""},"variation":null},"RN_LDP_SRP_REMOVE_CLICK_TO_CALL-RN_LDP_SRP_REMOVE_CLICK_TO_CALL_202309-{}":{"isEnabled":false,"variables":{"Variation":""},"variation":null},"BX_LDP_LCE_FOR_SALE_202401-BX_LDP_LCE_FOR_SALE_202401-{}":{"isEnabled":false,"variables":{"Variation":""},"variation":null},"bx_srp_cta_title-bx_srp_cta_title_20231017-{}":{"isEnabled":true,"variables":{},"variation":"C"},"BX_YMAL-BX_YMAL_202311-{}":{"isEnabled":false,"variables":{"Variation":""},"variation":null},"MEDIA_SRP_INTERSCROLL_DESKTOP-MEDIA_SRP_INTERSCROLL_DESKTOP_202311-{}":{"isEnabled":false,"variables":{"Variation":""},"variation":null},"MEDIA_SRP_INTERSCROLL_MWEB-MEDIA_SRP_INTERSCROLL_MWEB_202311-{}":{"isEnabled":false,"variables":{"Variation":""},"variation":null},"RN_LDP_SRP_GOOGLE_ONE_TAP-RN_LDP_SRP_GOOGLE_ONE_TAP_102023-{}":{"isEnabled":false,"variables":{"Variation":""},"variation":null},"NHC_BUILDER_PROMOTION_ENABLED-NHC_SRP_LDP_BUILDER_PROMO-{}":{"isEnabled":false,"variables":{},"variation":null},"FOR_SALE_SRP_GLOBAL_HOLDOUT_1-FOR_SALE_SRP_GLOBAL_HOLDOUT_AA_TEST_1_202310-{}":{"isEnabled":false,"variables":{"Variation":"V1"},"variation":null},"FOR_SALE_SRP_GLOBAL_HOLDOUT_2-FOR_SALE_SRP_GLOBAL_HOLDOUT_AA_TEST_2_202310-{}":{"isEnabled":false,"variables":{"Variation":"V1"},"variation":null},"FOR_RENT_SRP_GLOBAL_HOLDOUT_AA_TEST_1_202 ...
#           window.__OPTIMIZELY_INITIAL_PROPS__={"isDisabled":false,"userId":"6c89087f-4f0e-46e6-acd2-fd5e943b5590","attributes":{"origin":"x-web:realestateandhomes-search"},"userAgent":"Chrome/22.0.1207.1","usePrimedCacheWhenDisabled":true,"queryParams":{"slug":["Los-Angeles_CA"]},"project":"RDCX","env":"production","enableHoldouts":true}
#           </script></body></html>

# %%
#Realtor stored property titles in 2 parts

titles1 = []
titles = []

#Fitlering out 1st part of property titles
for title in bsobj.findAll('div', {'data-testid' : 'card-address-1'}):

  titles1.append(title.text)


#Counter for combining both parts sequentially
i = 0

#Filtering out 2nd part of property titles
for title in bsobj.findAll('div', {'data-testid' : 'card-address-2'}) :

  #Had some duplication issues in some cities in this part
  #temp = (re.split('[0-9][a-zA-Z]', title.text))[0]

  titles.append(titles1[i] + ' ' + title.text)

  i += 1


print(titles)
# Out:
# ['833 N Spaulding Ave Los Angeles, CA 90046', '1200 Bel Air Rd Los Angeles, CA 90077', '13691 Gavina Ave Unit 443 Sylmar, CA 91342', '13320 Mulholland Dr Beverly Hills, CA 90210', '9505 Gloaming Dr Beverly Hills, CA 90210', '3711 Fredonia Dr Los Angeles, CA 90068', '10644 Bellagio Rd Los Angeles, CA 90077', '5839 Cleon Ave North Hollywood, CA 91601', '13691 Gavina Ave Unit 649 Sylmar, CA 91342', '2650 Benedict Canyon Dr Beverly Hills, CA 90210', '594 S Mapleton Dr Los Angeles, CA 90024', '12960 Lemay St Valley Glen, CA 91606', '1322 Benedict Canyon Dr Beverly Hills, CA 90210', '7044 Alabama Ave Canoga Park, CA 91303', '2 Canterbury Dr Northridge, CA 91324', '1005 N Croft Ave Los Angeles, CA 90069', '16321 Pacific Coast Hwy Spc 72 Pacific Palisades, CA 90272', '5165 Avenida Hacienda Tarzana, CA 91356', '534 N LA Jolla Ave Los Angeles, CA 90048', '1625 Summitridge Dr Beverly Hills, CA 90210', '8928 Cayuga Ave Sun Valley, CA 91352', '5237 Live Oak View Ave Los Angeles, CA 90041', '2013 Walgrove Ave Los Angeles, CA 90066', '22605 Mulholland Dr Woodland Hills, CA 91364', '1071 S Point View St Los Angeles, CA 90035', '2172 Coldwater Canyon Dr Beverly Hills, CA 90210', '9421 Wentworth St Sunland, CA 91040', '5215 Onaknoll Ave Los Angeles, CA 90043', '3379 Tareco Dr Los Angeles, CA 90068', '539 E Avenue 39 Los Angeles, CA 90031', '2261 W 31st St Los Angeles, CA 90018', '16748 Knollwood Dr Granada Hills, CA 91344', '19705 Hamlin St Woodland Hills, CA 91367', '4811 Frieda Dr Los Angeles, CA 90065', '3110 Manitou Ave Los Angeles, CA 90031', '5326 Baza Ave Woodland Hills, CA 91364', '649 E 81st St Los Angeles, CA 90001', '6217 Scenic Ave Los Angeles, CA 90068', '2768 Wright Ln Los Angeles, CA 90068', '18451 Sunny Ln Tarzana, CA 91356', '21091 Topochico Dr Woodland Hills, CA 91364', '645 S Record Ave East Los Angeles, CA 90023', '12620 Classics Dr Granada Hills, CA 91344', '16748 Knollwood Dr Granada Hills, CA 91344', '17144 Barneston St Granada Hills, CA 91344', '16740 Knollwood Dr Granada Hills, CA 91344', '10331 Lindley Ave Unit 229 Porter Ranch, CA 91326', '12457 Bradford Pl Granada Hills, CA 91344', '11133 Monogram Ave Granada Hills, CA 91344', '11006-1008 Woodley Ave Granada Hills, CA 91344', '10636 Woodley Ave Unit 31 Granada Hills, CA 91344', '15762 Midwood Dr Unit 4 Granada Hills, CA 91344', '11993 Shoshone Ave Granada Hills, CA 91344', '16550 Knollwood Dr Granada Hills, CA 91344', '11957 Wood Ranch Rd Granada Hills, CA 91344', '12421 Jolette Ave Granada Hills, CA 91344', '11632 Babbitt Ave Granada Hills, CA 91344', '12124 Delante Way Granada Hills, CA 91344', '12700 Tyson Pl Granada Hills, CA 91344', '17761 Ridgeway Rd Granada Hills, CA 91344', '11624 Sophia Ave Granada Hills, CA 91344', '17457 Kingsbury St Granada Hills, CA 91344']

# %%
#Filtering out Property Prices
prices = []

for price in bsobj.findAll('div', {'data-testid' : 'card-price'}) :

  prices.append(price.text)

  print(price.text)
# Out:
# $4,695,000
# $139,000,000
# $325,000
# $9,500,000
# $126,000,000
# $444,000
# $195,000,000
# $2,999,999
# $319,000
# $44,800,000
# $155,000,000
# $899,000
# $2,895,000
# $3,085,000
# $99,000
# $13,950,000
# $599,000
# $6,500,000
# $4,695,000
# $45,950,000
# $1,075,000
# $1,899,000
# $3,095,000
# $1,550,000
# $2,195,000
# $4,195,000
# $850,000
# $1,349,000
# $2,590,000
# $999,000
# $1,049,000
# $1,575,000
# $1,199,000
# $1,200,000
# $698,500
# $1,150,000
# $680,000
# $1,975,000
# $1,298,000
# $1,595,000
# $1,199,000
# $638,800
# $2,100,000
# $1,575,000
# $1,495,000
# $1,649,999
# $449,000
# $1,235,000
# $900,000
# $999,999
# $595,000
# $584,950
# $2,500,000
# $1,699,000
# $2,899,500
# $1,200,000
# $1,099,000
# $2,899,999
# $1,395,000
# $1,790,000
# $1,299,000
# $739,000

# %%
#Filtering out Property Website Links
urls = []

for url in bsobj.findAll('a', {'class' : 'LinkComponent_anchor__0C2xC'}) :

  #Adding missing part for absolute paths
  if 'https://www.realtor.com/' + url['href'] in urls :

    continue

  urls.append('https://www.realtor.com/' + url['href'])



print(urls)
# Out:
# ['https://www.realtor.com//realestateandhomes-detail/833-N-Spaulding-Ave_Los-Angeles_CA_90046_M23371-92421?from=srp-list-card', 'https://www.realtor.com//realestateandhomes-detail/1200-Bel-Air-Rd_Los-Angeles_CA_90077_M17839-35941?from=srp-list-card', 'https://www.realtor.com//realestateandhomes-detail/13691-Gavina-Ave-Unit-443_Sylmar_CA_91342_M29808-52470?from=srp-list-card', 'https://www.realtor.com//realestateandhomes-detail/13320-Mulholland-Dr_Beverly-Hills_CA_90210_M27170-05592?from=srp-list-card', 'https://www.realtor.com//realestateandhomes-detail/9505-Gloaming-Dr_Beverly-Hills_CA_90210_M98694-39689?from=srp-list-card', 'https://www.realtor.com//realestateandhomes-detail/3711-Fredonia-Dr_Los-Angeles_CA_90068_M21158-62468?from=srp-list-card', 'https://www.realtor.com//realestateandhomes-detail/10644-Bellagio-Rd_Los-Angeles_CA_90077_M10461-12528?from=srp-list-card', 'https://www.realtor.com//realestateandhomes-detail/5839-Cleon-Ave_North-Hollywood_CA_91601_M16884-07492?from=srp-list-card', 'https://www.realtor.com//realestateandhomes-detail/13691-Gavina-Ave-Unit-649_Sylmar_CA_91342_M24698-16008?from=srp-list-card', 'https://www.realtor.com//realestateandhomes-detail/2650-Benedict-Canyon-Dr_Beverly-Hills_CA_90210_M24995-96083?from=srp-list-card', 'https://www.realtor.com//realestateandhomes-detail/594-S-Mapleton-Dr_Los-Angeles_CA_90024_M27214-75059?from=srp-list-card', 'https://www.realtor.com//realestateandhomes-detail/12960-Lemay-St_North-Hollywood_CA_91606_M18702-91280?from=srp-list-card', 'https://www.realtor.com//realestateandhomes-detail/1322-Benedict-Canyon-Dr_Beverly-Hills_CA_90210_M13084-59781?from=srp-list-card', 'https://www.realtor.com//realestateandhomes-detail/7044-Alabama-Ave_Canoga-Park_CA_91303_M15239-68816?from=srp-list-card', 'https://www.realtor.com//realestateandhomes-detail/2-Canterbury-Dr_Northridge_CA_91324_M93551-94915?from=srp-list-card', 'https://www.realtor.com//realestateandhomes-detail/1005-N-Croft-Ave_Los-Angeles_CA_90069_M94151-17303?from=srp-list-card', 'https://www.realtor.com//realestateandhomes-detail/16321-Pacific-Coast-Hwy-Spc-72_Pacific-Palisades_CA_90272_M99496-51453?from=srp-list-card', 'https://www.realtor.com//realestateandhomes-detail/5165-Avenida-Hacienda_Tarzana_CA_91356_M15234-79897?from=srp-list-card', 'https://www.realtor.com//realestateandhomes-detail/534-N-LA-Jolla-Ave_Los-Angeles_CA_90048_M23512-41682?from=srp-list-card', 'https://www.realtor.com//realestateandhomes-detail/1625-Summitridge-Dr_Beverly-Hills_CA_90210_M12609-82970?from=srp-list-card', 'https://www.realtor.com//realestateandhomes-detail/8928-Cayuga-Ave_Sun-Valley_CA_91352_M23849-74360?from=srp-list-card', 'https://www.realtor.com//realestateandhomes-detail/5237-Live-Oak-View-Ave_Los-Angeles_CA_90041_M12262-71930?from=srp-list-card', 'https://www.realtor.com//realestateandhomes-detail/2013-Walgrove-Ave_Los-Angeles_CA_90066_M18832-35157?from=srp-list-card', 'https://www.realtor.com//realestateandhomes-detail/22605-Mulholland-Dr_Woodland-Hills_CA_91364_M28708-90059?from=srp-list-card', 'https://www.realtor.com//realestateandhomes-detail/1071-S-Point-View-St_Los-Angeles_CA_90035_M21332-44142?from=srp-list-card', 'https://www.realtor.com//realestateandhomes-detail/2172-Coldwater-Canyon-Dr_Beverly-Hills_CA_90210_M28064-25327?from=srp-list-card', 'https://www.realtor.com//realestateandhomes-detail/9421-Wentworth-St_Sunland_CA_91040_M26599-33856?from=srp-list-card', 'https://www.realtor.com//realestateandhomes-detail/5215-Onaknoll-Ave_Los-Angeles_CA_90043_M20540-28120?from=srp-list-card', 'https://www.realtor.com//realestateandhomes-detail/3379-Tareco-Dr_Los-Angeles_CA_90068_M13188-51904?from=srp-list-card', 'https://www.realtor.com//realestateandhomes-detail/539-E-Avenue-39_Los-Angeles_CA_90031_M14518-25010?from=srp-list-card', 'https://www.realtor.com//realestateandhomes-detail/2261-W-31st-St_Los-Angeles_CA_90018_M12138-18808?from=srp-list-card', 'https://www.realtor.com//realestateandhomes-detail/16748-Knollwood-Dr ...

# %%
#Combining all attributes
data = {'Properties': [{'Title': t, 'Price': p, 'Url': u} for t, p, u in zip(titles, prices, urls)]}
print(data)

#Converting to JSON Format
json_data = json.dumps(data, indent = 5)

print(json_data)
# Out:
# {'Properties': [{'Title': '833 N Spaulding Ave Los Angeles, CA 90046', 'Price': '$4,695,000', 'Url': 'https://www.realtor.com//realestateandhomes-detail/833-N-Spaulding-Ave_Los-Angeles_CA_90046_M23371-92421?from=srp-list-card'}, {'Title': '1200 Bel Air Rd Los Angeles, CA 90077', 'Price': '$139,000,000', 'Url': 'https://www.realtor.com//realestateandhomes-detail/1200-Bel-Air-Rd_Los-Angeles_CA_90077_M17839-35941?from=srp-list-card'}, {'Title': '13691 Gavina Ave Unit 443 Sylmar, CA 91342', 'Price': '$325,000', 'Url': 'https://www.realtor.com//realestateandhomes-detail/13691-Gavina-Ave-Unit-443_Sylmar_CA_91342_M29808-52470?from=srp-list-card'}, {'Title': '13320 Mulholland Dr Beverly Hills, CA 90210', 'Price': '$9,500,000', 'Url': 'https://www.realtor.com//realestateandhomes-detail/13320-Mulholland-Dr_Beverly-Hills_CA_90210_M27170-05592?from=srp-list-card'}, {'Title': '9505 Gloaming Dr Beverly Hills, CA 90210', 'Price': '$126,000,000', 'Url': 'https://www.realtor.com//realestateandhomes-detail/9505-Gloaming-Dr_Beverly-Hills_CA_90210_M98694-39689?from=srp-list-card'}, {'Title': '3711 Fredonia Dr Los Angeles, CA 90068', 'Price': '$444,000', 'Url': 'https://www.realtor.com//realestateandhomes-detail/3711-Fredonia-Dr_Los-Angeles_CA_90068_M21158-62468?from=srp-list-card'}, {'Title': '10644 Bellagio Rd Los Angeles, CA 90077', 'Price': '$195,000,000', 'Url': 'https://www.realtor.com//realestateandhomes-detail/10644-Bellagio-Rd_Los-Angeles_CA_90077_M10461-12528?from=srp-list-card'}, {'Title': '5839 Cleon Ave North Hollywood, CA 91601', 'Price': '$2,999,999', 'Url': 'https://www.realtor.com//realestateandhomes-detail/5839-Cleon-Ave_North-Hollywood_CA_91601_M16884-07492?from=srp-list-card'}, {'Title': '13691 Gavina Ave Unit 649 Sylmar, CA 91342', 'Price': '$319,000', 'Url': 'https://www.realtor.com//realestateandhomes-detail/13691-Gavina-Ave-Unit-649_Sylmar_CA_91342_M24698-16008?from=srp-list-card'}, {'Title': '2650 Benedict Canyon Dr Beverly Hills, CA 90210', 'Price': '$44,800,000', 'Url': 'https://www.realtor.com//realestateandhomes-detail/2650-Benedict-Canyon-Dr_Beverly-Hills_CA_90210_M24995-96083?from=srp-list-card'}, {'Title': '594 S Mapleton Dr Los Angeles, CA 90024', 'Price': '$155,000,000', 'Url': 'https://www.realtor.com//realestateandhomes-detail/594-S-Mapleton-Dr_Los-Angeles_CA_90024_M27214-75059?from=srp-list-card'}, {'Title': '12960 Lemay St Valley Glen, CA 91606', 'Price': '$899,000', 'Url': 'https://www.realtor.com//realestateandhomes-detail/12960-Lemay-St_North-Hollywood_CA_91606_M18702-91280?from=srp-list-card'}, {'Title': '1322 Benedict Canyon Dr Beverly Hills, CA 90210', 'Price': '$2,895,000', 'Url': 'https://www.realtor.com//realestateandhomes-detail/1322-Benedict-Canyon-Dr_Beverly-Hills_CA_90210_M13084-59781?from=srp-list-card'}, {'Title': '7044 Alabama Ave Canoga Park, CA 91303', 'Price': '$3,085,000', 'Url': 'https://www.realtor.com//realestateandhomes-detail/7044-Alabama-Ave_Canoga-Park_CA_91303_M15239-68816?from=srp-list-card'}, {'Title': '2 Canterbury Dr Northridge, CA 91324', 'Price': '$99,000', 'Url': 'https://www.realtor.com//realestateandhomes-detail/2-Canterbury-Dr_Northridge_CA_91324_M93551-94915?from=srp-list-card'}, {'Title': '1005 N Croft Ave Los Angeles, CA 90069', 'Price': '$13,950,000', 'Url': 'https://www.realtor.com//realestateandhomes-detail/1005-N-Croft-Ave_Los-Angeles_CA_90069_M94151-17303?from=srp-list-card'}, {'Title': '16321 Pacific Coast Hwy Spc 72 Pacific Palisades, CA 90272', 'Price': '$599,000', 'Url': 'https://www.realtor.com//realestateandhomes-detail/16321-Pacific-Coast-Hwy-Spc-72_Pacific-Palisades_CA_90272_M99496-51453?from=srp-list-card'}, {'Title': '5165 Avenida Hacienda Tarzana, CA 91356', 'Price': '$6,500,000', 'Url': 'https://www.realtor.com//realestateandhomes-detail/5165-Avenida-Hacienda_Tarzana_CA_91356_M15234-79897?from=srp-list-card'}, {'Title': '534 N LA Jolla Ave Los Angeles, CA 90048', 'Price': '$4,695,000', 'Url': 'https://www.realtor.com//realestateandhomes-detail/534-N-LA- ...
# {
#      "Properties": [
#           {
#                "Title": "833 N Spaulding Ave Los Angeles, CA 90046",
#                "Price": "$4,695,000",
#                "Url": "https://www.realtor.com//realestateandhomes-detail/833-N-Spaulding-Ave_Los-Angeles_CA_90046_M23371-92421?from=srp-list-card"
#           },
#           {
#                "Title": "1200 Bel Air Rd Los Angeles, CA 90077",
#                "Price": "$139,000,000",
#                "Url": "https://www.realtor.com//realestateandhomes-detail/1200-Bel-Air-Rd_Los-Angeles_CA_90077_M17839-35941?from=srp-list-card"
#           },
#           {
#                "Title": "13691 Gavina Ave Unit 443 Sylmar, CA 91342",
#                "Price": "$325,000",
#                "Url": "https://www.realtor.com//realestateandhomes-detail/13691-Gavina-Ave-Unit-443_Sylmar_CA_91342_M29808-52470?from=srp-list-card"
#           },
#           {
#                "Title": "13320 Mulholland Dr Beverly Hills, CA 90210",
#                "Price": "$9,500,000",
#                "Url": "https://www.realtor.com//realestateandhomes-detail/13320-Mulholland-Dr_Beverly-Hills_CA_90210_M27170-05592?from=srp-list-card"
#           },
#           {
#                "Title": "9505 Gloaming Dr Beverly Hills, CA 90210",
#                "Price": "$126,000,000",
#                "Url": "https://www.realtor.com//realestateandhomes-detail/9505-Gloaming-Dr_Beverly-Hills_CA_90210_M98694-39689?from=srp-list-card"
#           },
#           {
#                "Title": "3711 Fredonia Dr Los Angeles, CA 90068",
#                "Price": "$444,000",
#                "Url": "https://www.realtor.com//realestateandhomes-detail/3711-Fredonia-Dr_Los-Angeles_CA_90068_M21158-62468?from=srp-list-card"
#           },
#           {
#                "Title": "10644 Bellagio Rd Los Angeles, CA 90077",
#                "Price": "$195,000,000",
#                "Url": "https://www.realtor.com//realestateandhomes-detail/10644-Bellagio-Rd_Los-Angeles_CA_90077_M10461-12528?from=srp-list-card"
#           },
#           {
#                "Title": "5839 Cleon Ave North Hollywood, CA 91601",
#                "Price": "$2,999,999",
#                "Url": "https://www.realtor.com//realestateandhomes-detail/5839-Cleon-Ave_North-Hollywood_CA_91601_M16884-07492?from=srp-list-card"
#           },
#           {
#                "Title": "13691 Gavina Ave Unit 649 Sylmar, CA 91342",
#                "Price": "$319,000",
#                "Url": "https://www.realtor.com//realestateandhomes-detail/13691-Gavina-Ave-Unit-649_Sylmar_CA_91342_M24698-16008?from=srp-list-card"
#           },
#           {
#                "Title": "2650 Benedict Canyon Dr Beverly Hills, CA 90210",
#                "Price": "$44,800,000",
#                "Url": "https://www.realtor.com//realestateandhomes-detail/2650-Benedict-Canyon-Dr_Beverly-Hills_CA_90210_M24995-96083?from=srp-list-card"
#           },
#           {
#                "Title": "594 S Mapleton Dr Los Angeles, CA 90024",
#                "Price": "$155,000,000",
#                "Url": "https://www.realtor.com//realestateandhomes-detail/594-S-Mapleton-Dr_Los-Angeles_CA_90024_M27214-75059?from=srp-list-card"
#           },
#           {
#                "Title": "12960 Lemay St Valley Glen, CA 91606",
#                "Price": "$899,000",
#                "Url": "https://www.realtor.com//realestateandhomes-detail/12960-Lemay-St_North-Hollywood_CA_91606_M18702-91280?from=srp-list-card"
#           },
#           {
#                "Title": "1322 Benedict Canyon Dr Beverly Hills, CA 90210",
#                "Price": "$2,895,000",
#                "Url": "https://www.realtor.com//realestateandhomes-detail/1322-Benedict-Canyon-Dr_Beverly-Hills_CA_90210_M13084-59781?from=srp-list-card"
#           },
#           {
#                "Title": "7044 Alabama Ave Canoga Park, CA 91303",
#                "Price": "$3,085,000",
#                "Url": "https://www.realtor.com//realestateandhomes-detail/7044-Alabama-Ave_Canoga-Park_CA_91303_M15239-68816?from=srp-list-card"
#           },
#           {
#                "Title": "2 Canterbury Dr Northridge, CA 91324",
#                "Price": "$99,000",
#                "Url": "https://www.realtor.com//realestateandhomes-detail/2-Canterbury-Dr_Northridge_CA_91324_M93551-94915?from=srp-list-card"
#           },
#           {
#                "Title": "1005 N Croft Ave Los Angeles, CA 90069",
#                "Price": "$13,950,000",
#                "Url": "https://www.realtor.com//realestateandhomes-detail/1005-N-Croft-Ave_Los-Angeles_CA_90069_M94151-17303?from=srp-list-card"
#           },
#           {
#                "Title": "16321 Pacific Coast Hwy Spc 72 Pacific Palisades, CA 90272",
#                "Price": "$599,000",
#                "Url": "https://www.realtor.com//realestateandhomes-detail/16321-Pacific-Coast-Hwy-Spc-72_Pacific-Palisades_CA_90272_M99496-51453?from=srp-list-card"
#           },
#           {
#                "Title": "5165 Avenida Hacienda Tarzana, CA 91356",
#                "Price": "$6,500,000",
#                "Url": "https://www.realtor.com//realestateandhomes-detail/5165-Avenida-Hacienda_Tarzana_CA_91356_M15234-79897?from=srp-list-card"
#           },
#           {
#                "Title": "534 N LA Jolla Ave Los Angeles, CA 90048",
#                "Price": "$4,695,000",
#                "Url": "https://www.realtor.com//realestateandhomes-detail/534-N-LA-Jolla-Ave_Los-Angeles_CA_90048_M23512-41682?from=srp-list-card"
#           },
#           {
#                "Title": "1625 Summitridge Dr Beverly Hills, CA 90210",
#                "Price": "$45,950,000",
#                "Url": "https://www.realtor.com//realestateandhomes-detail/1625-Summitridge-Dr_Beverly-Hills_CA_90210_M12609-82970?from=srp-list-card"
#           },
#           {
#                "Title": "8928 Cayuga Ave Sun Valley, CA 91352",
#                "Price": "$1,075,000",
#                "Url": "https://www.realtor.com//realestateandhomes-detail/8928-Cayuga-Ave_Sun-Valley_CA_91352_M23849-74360?from=srp-list-card"
#           },
#           {
#                "Title": "5237 Live Oak View Ave Los Angeles, CA 90041",
#                "Price": "$1,899,000",
#                "Url": "https://www.realtor.com//realestateandhomes-detail/5237-Live-Oak-View-Ave_Los-Angeles_CA_90041_M12262-71930?from=srp-list-card"
#           },
#           {
#                "Title": "2013 Walgrove Ave Los Angeles, CA 90066",
#                "Price": "$3,095,000",
#                "Url": "https://www.realtor.com//realestateandhomes-detail/2013-Walgrove-Ave_Los-Angeles_CA_90066_M18832-35157?from=srp-list-card"
#           },
#           {
#                "Title": "22605 Mulholland Dr Woodland Hills, CA 91364",
#                "Price": "$1,550,000",
#                "Url": "https://www.realtor.com//realestateandhomes-detail/22605-Mulholland-Dr_Woodland-Hills_CA_91364_M28708-90059?from=srp-list-card"
#           },
#           {
#                "Title": "1071 S Point View St Los Angeles, CA 90035",
#                "Price": "$2,195,000",
#                "Url": "https://www.realtor.com//realestateandhomes-detail/1071-S-Point-View-St_Los-Angeles_CA_90035_M21332-44142?from=srp-list-card"
#           },
#           {
#                "Title": "2172 Coldwater Canyon Dr Beverly Hills, CA 90210",
#                "Price": "$4,195,000",
#                "Url": "https://www.realtor.com//realestateandhomes-detail/2172-Coldwater-Canyon-Dr_Beverly-Hills_CA_90210_M28064-25327?from=srp-list-card"
#           },
#           {
#                "Title": "9421 Wentworth St Sunland, CA 91040",
#                "Price": "$850,000",
#                "Url": "https://www.realtor.com//realestateandhomes-detail/9421-Wentworth-St_Sunland_CA_91040_M26599-33856?from=srp-list-card"
#           },
#           {
#                "Title": "5215 Onaknoll Ave Los Angeles, CA 90043",
#                "Price": "$1,349,000",
#                "Url": "https://www.realtor.com//realestateandhomes-detail/5215-Onaknoll-Ave_Los-Angeles_CA_90043_M20540-28120?from=srp-list-card"
#           },
#           {
#                "Title": "3379 Tareco Dr Los Angeles, CA 90068",
#                "Price": "$2,590,000",
#                "Url": "https://www.realtor.com//realestateandhomes-detail/3379-Tareco-Dr_Los-Angeles_CA_90068_M13188-51904?from=srp-list-card"
#           },
#           {
#                "Title": "539 E Avenue 39 Los Angeles, CA 90031",
#                "Price": "$999,000",
#                "Url": "https://www.realtor.com//realestateandhomes-detail/539-E-Avenue-39_Los-Angeles_CA_90031_M14518-25010?from=srp-list-card"
#           },
#           {
#                "Title": "2261 W 31st St Los Angeles, CA 90018",
#                "Price": "$1,049,000",
#                "Url": "https://www.realtor.com//realestateandhomes-detail/2261-W-31st-St_Los-Angeles_CA_90018_M12138-18808?from=srp-list-card"
#           },
#           {
#                "Title": "16748 Knollwood Dr Granada Hills, CA 91344",
#                "Price": "$1,575,000",
#                "Url": "https://www.realtor.com//realestateandhomes-detail/16748-Knollwood-Dr_Granada-Hills_CA_91344_M17680-73948?from=srp-list-card"
#           },
#           {
#                "Title": "19705 Hamlin St Woodland Hills, CA 91367",
#                "Price": "$1,199,000",
#                "Url": "https://www.realtor.com//realestateandhomes-detail/19705-Hamlin-St_Woodland-Hills_CA_91367_M26544-38092?from=srp-list-card"
#           },
#           {
#                "Title": "4811 Frieda Dr Los Angeles, CA 90065",
#                "Price": "$1,200,000",
#                "Url": "https://www.realtor.com//realestateandhomes-detail/4811-Frieda-Dr_Los-Angeles_CA_90065_M14330-83390?from=srp-list-card"
#           },
#           {
#                "Title": "3110 Manitou Ave Los Angeles, CA 90031",
#                "Price": "$698,500",
#                "Url": "https://www.realtor.com//realestateandhomes-detail/3110-Manitou-Ave_Los-Angeles_CA_90031_M15014-25980?from=srp-list-card"
#           },
#           {
#                "Title": "5326 Baza Ave Woodland Hills, CA 91364",
#                "Price": "$1,150,000",
#                "Url": "https://www.realtor.com//realestateandhomes-detail/5326-Baza-Ave_Woodland-Hills_CA_91364_M18183-28035?from=srp-list-card"
#           },
#           {
#                "Title": "649 E 81st St Los Angeles, CA 90001",
#                "Price": "$680,000",
#                "Url": "https://www.realtor.com//realestateandhomes-detail/649-E-81st-St_Los-Angeles_CA_90001_M13684-56022?from=srp-list-card"
#           },
#           {
#                "Title": "6217 Scenic Ave Los Angeles, CA 90068",
#                "Price": "$1,975,000",
#                "Url": "https://www.realtor.com//realestateandhomes-detail/6217-Scenic-Ave_Los-Angeles_CA_90068_M13575-71218?from=srp-list-card"
#           },
#           {
#                "Title": "2768 Wright Ln Los Angeles, CA 90068",
#                "Price": "$1,298,000",
#                "Url": "https://www.realtor.com//realestateandhomes-detail/2768-Wright-Ln_Los-Angeles_CA_90068_M20421-07449?from=srp-list-card"
#           },
#           {
#                "Title": "18451 Sunny Ln Tarzana, CA 91356",
#                "Price": "$1,595,000",
#                "Url": "https://www.realtor.com//realestateandhomes-detail/18451-Sunny-Ln_Tarzana_CA_91356_M15050-70522?from=srp-list-card"
#           },
#           {
#                "Title": "21091 Topochico Dr Woodland Hills, CA 91364",
#                "Price": "$1,199,000",
#                "Url": "https://www.realtor.com//realestateandhomes-detail/21091-Topochico-Dr_Woodland-Hills_CA_91364_M18894-31453?from=srp-list-card"
#           },
#           {
#                "Title": "645 S Record Ave East Los Angeles, CA 90023",
#                "Price": "$638,800",
#                "Url": "https://www.realtor.com//realestateandhomes-detail/645-S-Record-Ave_Los-Angeles_CA_90023_M21348-35205?from=srp-list-card"
#           },
#           {
#                "Title": "12620 Classics Dr Granada Hills, CA 91344",
#                "Price": "$2,100,000",
#                "Url": "https://www.realtor.com//realestateandhomes-detail/12620-Classics-Dr_Granada-Hills_CA_91344_M14180-34950?from=srp-list-card"
#           },
#           {
#                "Title": "16748 Knollwood Dr Granada Hills, CA 91344",
#                "Price": "$1,575,000",
#                "Url": "https://www.realtor.com//realestateandhomes-detail/17144-Barneston-St_Granada-Hills_CA_91344_M15659-06210?from=srp-list-card"
#           },
#           {
#                "Title": "17144 Barneston St Granada Hills, CA 91344",
#                "Price": "$1,495,000",
#                "Url": "https://www.realtor.com//realestateandhomes-detail/16740-Knollwood-Dr_Granada-Hills_CA_91344_M17543-22815?from=srp-list-card"
#           },
#           {
#                "Title": "16740 Knollwood Dr Granada Hills, CA 91344",
#                "Price": "$1,649,999",
#                "Url": "https://www.realtor.com//realestateandhomes-detail/10331-Lindley-Ave-Unit-229_Porter-Ranch_CA_91326_M28281-14596?from=srp-list-card"
#           },
#           {
#                "Title": "10331 Lindley Ave Unit 229 Porter Ranch, CA 91326",
#                "Price": "$449,000",
#                "Url": "https://www.realtor.com//realestateandhomes-detail/12457-Bradford-Pl_Granada-Hills_CA_91344_M16853-43556?from=srp-list-card"
#           },
#           {
#                "Title": "12457 Bradford Pl Granada Hills, CA 91344",
#                "Price": "$1,235,000",
#                "Url": "https://www.realtor.com//realestateandhomes-detail/11133-Monogram-Ave_Granada-Hills_CA_91344_M14981-82620?from=srp-list-card"
#           },
#           {
#                "Title": "11133 Monogram Ave Granada Hills, CA 91344",
#                "Price": "$900,000",
#                "Url": "https://www.realtor.com//realestateandhomes-detail/11006-Woodley-Ave_Granada-Hills_CA_91344_M12408-61287?from=srp-list-card"
#           },
#           {
#                "Title": "11006-1008 Woodley Ave Granada Hills, CA 91344",
#                "Price": "$999,999",
#                "Url": "https://www.realtor.com//realestateandhomes-detail/10636-Woodley-Ave-Unit-31_Granada-Hills_CA_91344_M12608-35832?from=srp-list-card"
#           },
#           {
#                "Title": "10636 Woodley Ave Unit 31 Granada Hills, CA 91344",
#                "Price": "$595,000",
#                "Url": "https://www.realtor.com//realestateandhomes-detail/15762-Midwood-Dr-Unit-4_Granada-Hills_CA_91344_M15335-22106?from=srp-list-card"
#           },
#           {
#                "Title": "15762 Midwood Dr Unit 4 Granada Hills, CA 91344",
#                "Price": "$584,950",
#                "Url": "https://www.realtor.com//realestateandhomes-detail/11993-Shoshone-Ave_Granada-Hills_CA_91344_M13723-09639?from=srp-list-card"
#           },
#           {
#                "Title": "11993 Shoshone Ave Granada Hills, CA 91344",
#                "Price": "$2,500,000",
#                "Url": "https://www.realtor.com//realestateandhomes-detail/16550-Knollwood-Dr_Granada-Hills_CA_91344_M17422-48650?from=srp-list-card"
#           },
#           {
#                "Title": "16550 Knollwood Dr Granada Hills, CA 91344",
#                "Price": "$1,699,000",
#                "Url": "https://www.realtor.com//realestateandhomes-detail/11957-Wood-Ranch-Rd_Granada-Hills_CA_91344_M14453-50886?from=srp-list-card"
#           },
#           {
#                "Title": "11957 Wood Ranch Rd Granada Hills, CA 91344",
#                "Price": "$2,899,500",
#                "Url": "https://www.realtor.com//realestateandhomes-detail/12421-Jolette-Ave_Granada-Hills_CA_91344_M17102-37205?from=srp-list-card"
#           },
#           {
#                "Title": "12421 Jolette Ave Granada Hills, CA 91344",
#                "Price": "$1,200,000",
#                "Url": "https://www.realtor.com//realestateandhomes-detail/11632-Babbitt-Ave_Granada-Hills_CA_91344_M16630-21256?from=srp-list-card"
#           },
#           {
#                "Title": "11632 Babbitt Ave Granada Hills, CA 91344",
#                "Price": "$1,099,000",
#                "Url": "https://www.realtor.com//realestateandhomes-detail/12124-Delante-Way_Granada-Hills_CA_91344_M20397-19618?from=srp-list-card"
#           },
#           {
#                "Title": "12124 Delante Way Granada Hills, CA 91344",
#                "Price": "$2,899,999",
#                "Url": "https://www.realtor.com//realestateandhomes-detail/12700-Tyson-Pl_Granada-Hills_CA_91344_M16551-20876?from=srp-list-card"
#           },
#           {
#                "Title": "12700 Tyson Pl Granada Hills, CA 91344",
#                "Price": "$1,395,000",
#                "Url": "https://www.realtor.com//realestateandhomes-detail/17761-Ridgeway-Rd_Granada-Hills_CA_91344_M13916-87929?from=srp-list-card"
#           },
#           {
#                "Title": "17761 Ridgeway Rd Granada Hills, CA 91344",
#                "Price": "$1,790,000",
#                "Url": "https://www.realtor.com//realestateandhomes-detail/11624-Sophia-Ave_Granada-Hills_CA_91344_M15909-48923?from=srp-list-card"
#           },
#           {
#                "Title": "11624 Sophia Ave Granada Hills, CA 91344",
#                "Price": "$1,299,000",
#                "Url": "https://www.realtor.com//realestateandhomes-detail/17457-Kingsbury-St_Granada-Hills_CA_91344_M23863-41828?from=srp-list-card"
#           }
#      ]
# }

# %%
#Writing JSON to File
with open('properties.json', 'w', encoding='utf-8') as file:
    json.dump(data, file, ensure_ascii=False, indent=5)
